# %%
import os
import re
import nltk
from nltk.corpus import stopwords

# %% [markdown]
# ### Cleaning all the scraped texts present in the .txt files using the 'StopWords' folder and saving the cleaned texts in the original .txt files.

# %%
import os

# Function to load stop words from the StopWords folder
def load_stopwords(stopwords_dir):
    stop_words = set()
    # Loop through all files in the StopWords directory
    for filename in os.listdir(stopwords_dir):
        if filename.endswith(".txt"):  # Assuming stop words are in .txt files
            filepath = os.path.join(stopwords_dir, filename)
            try:
                # Attempt to open the file with 'utf-8' encoding, fallback to 'latin-1' if error occurs
                with open(filepath, 'r', encoding='utf-8', errors='ignore') as file:
                    words = file.read().splitlines()
                    stop_words.update(words)
            except UnicodeDecodeError as e:
                print(f"Error reading {filename}: {e}")
    return stop_words

# Function to clean text by removing stop words
def clean_text(text, stop_words):
    # Tokenize text into words (this can be improved using nltk)
    words = text.split()  # Simple tokenization, splitting by whitespace
    
    # Remove stop words
    cleaned_words = [word for word in words if word.lower() not in stop_words]
    
    # Rejoin the cleaned words back into text
    cleaned_text = ' '.join(cleaned_words)
    return cleaned_text

# Load all stop words from the folder
stopwords_dir = 'StopWords'  # Replace with the actual path to the StopWords folder
stop_words = load_stopwords(stopwords_dir)

# Directory containing the article .txt files
articles_dir = 'scraped_articles'  # Replace with the folder where you saved your articles

# Loop through all .txt files in the articles directory
for filename in os.listdir(articles_dir):
    if filename.endswith(".txt"):
        filepath = os.path.join(articles_dir, filename)
        
        # Read the content of the article
        with open(filepath, 'r', encoding='utf-8', errors='ignore') as file:
            article_text = file.read()
        
        # Perform cleaning by removing stop words
        cleaned_text = clean_text(article_text, stop_words)
        
        # Overwrite the original .txt file with the cleaned text
        with open(filepath, 'w', encoding='utf-8') as file:
            file.write(cleaned_text)
        
        print(f"Successfully cleaned and saved {filename}")
# Out:
# Successfully cleaned and saved bctech2011.txt
# Successfully cleaned and saved bctech2012.txt
# Successfully cleaned and saved bctech2013.txt
# Successfully cleaned and saved bctech2014.txt
# Successfully cleaned and saved bctech2015.txt
# Successfully cleaned and saved bctech2016.txt
# Successfully cleaned and saved bctech2017.txt
# Successfully cleaned and saved bctech2018.txt
# Successfully cleaned and saved bctech2019.txt
# Successfully cleaned and saved bctech2020.txt
# Successfully cleaned and saved bctech2021.txt
# Successfully cleaned and saved bctech2022.txt
# Successfully cleaned and saved bctech2023.txt
# Successfully cleaned and saved bctech2024.txt
# Successfully cleaned and saved bctech2025.txt
# Successfully cleaned and saved bctech2026.txt
# Successfully cleaned and saved bctech2027.txt
# Successfully cleaned and saved bctech2028.txt
# Successfully cleaned and saved bctech2029.txt
# Successfully cleaned and saved bctech2030.txt
# Successfully cleaned and saved bctech2031.txt
# Successfully cleaned and saved bctech2032.txt
# Successfully cleaned and saved bctech2033.txt
# Successfully cleaned and saved bctech2034.txt
# Successfully cleaned and saved bctech2035.txt
# Successfully cleaned and saved bctech2036.txt
# Successfully cleaned and saved bctech2037.txt
# Successfully cleaned and saved bctech2038.txt
# Successfully cleaned and saved bctech2039.txt
# Successfully cleaned and saved bctech2040.txt
# Successfully cleaned and saved bctech2041.txt
# Successfully cleaned and saved bctech2042.txt
# Successfully cleaned and saved bctech2043.txt
# Successfully cleaned and saved bctech2044.txt
# Successfully cleaned and saved bctech2045.txt
# Successfully cleaned and saved bctech2046.txt
# Successfully cleaned and saved bctech2047.txt
# Successfully cleaned and saved bctech2048.txt
# Successfully cleaned and saved bctech2049.txt
# Successfully cleaned and saved bctech2050.txt
# Successfully cleaned and saved bctech2051.txt
# Successfully cleaned and saved bctech2052.txt
# Successfully cleaned and saved bctech2053.txt
# Successfully cleaned and saved bctech2054.txt
# Successfully cleaned and saved bctech2055.txt
# Successfully cleaned and saved bctech2056.txt
# Successfully cleaned and saved bctech2057.txt
# Successfully cleaned and saved bctech2058.txt
# Successfully cleaned and saved bctech2059.txt
# Successfully cleaned and saved bctech2060.txt
# Successfully cleaned and saved bctech2061.txt
# Successfully cleaned and saved bctech2062.txt
# Successfully cleaned and saved bctech2063.txt
# Successfully cleaned and saved bctech2064.txt
# Successfully cleaned and saved bctech2065.txt
# Successfully cleaned and saved bctech2066.txt
# Successfully cleaned and saved bctech2067.txt
# Successfully cleaned and saved bctech2068.txt
# Successfully cleaned and saved bctech2069.txt
# Successfully cleaned and saved bctech2070.txt
# Successfully cleaned and saved bctech2071.txt
# Successfully cleaned and saved bctech2072.txt
# Successfully cleaned and saved bctech2073.txt
# Successfully cleaned and saved bctech2074.txt
# Successfully cleaned and saved bctech2075.txt
# Successfully cleaned and saved bctech2076.txt
# Successfully cleaned and saved bctech2077.txt
# Successfully cleaned and saved bctech2078.txt
# Successfully cleaned and saved bctech2079.txt
# Successfully cleaned and saved bctech2080.txt
# Successfully cleaned and saved bctech2081.txt
# Successfully cleaned and saved bctech2082.txt
# Successfully cleaned and saved bctech2083.txt
# Successfully cleaned and saved bctech2084.txt
# Successfully cleaned and saved bctech2085.txt
# Successfully cleaned and saved bctech2086.txt
# Successfully cleaned and saved bctech2087.txt
# Successfully cleaned and saved bctech2088.txt
# Successfully cleaned and saved bctech2089.txt
# Successfully cleaned and saved bctech2090.txt
# Successfully cleaned and saved bctech2091.txt
# Successfully cleaned and saved bctech2092.txt
# Successfully cleaned and saved bctech2093.txt
# Successfully cleaned and saved bctech2094.txt
# Successfully cleaned and saved bctech2095.txt
# Successfully cleaned and saved bctech2096.txt
# Successfully cleaned and saved bctech2097.txt
# Successfully cleaned and saved bctech2098.txt
# Successfully cleaned and saved bctech2099.txt
# Successfully cleaned and saved bctech2100.txt
# Successfully cleaned and saved bctech2101.txt
# Successfully cleaned and saved bctech2102.txt
# Successfully cleaned and saved bctech2103.txt
# Successfully cleaned and saved bctech2104.txt
# Successfully cleaned and saved bctech2105.txt
# Successfully cleaned and saved bctech2106.txt
# Successfully cleaned and saved bctech2107.txt
# Successfully cleaned and saved bctech2108.txt
# Successfully cleaned and saved bctech2109.txt
# Successfully cleaned and saved bctech2110.txt
# Successfully cleaned and saved bctech2111.txt
# Successfully cleaned and saved bctech2112.txt
# Successfully cleaned and saved bctech2113.txt
# Successfully cleaned and saved bctech2114.txt
# Successfully cleaned and saved bctech2115.txt
# Successfully cleaned and saved bctech2116.txt
# Successfully cleaned and saved bctech2117.txt
# Successfully cleaned and saved bctech2118.txt
# Successfully cleaned and saved bctech2119.txt
# Successfully cleaned and saved bctech2120.txt
# Successfully cleaned and saved bctech2121.txt
# Successfully cleaned and saved bctech2122.txt
# Successfully cleaned and saved bctech2123.txt
# Successfully cleaned and saved bctech2124.txt
# Successfully cleaned and saved bctech2125.txt
# Successfully cleaned and saved bctech2126.txt
# Successfully cleaned and saved bctech2127.txt
# Successfully cleaned and saved bctech2128.txt
# Successfully cleaned and saved bctech2129.txt
# Successfully cleaned and saved bctech2130.txt
# Successfully cleaned and saved bctech2131.txt
# Successfully cleaned and saved bctech2132.txt
# Successfully cleaned and saved bctech2133.txt
# Successfully cleaned and saved bctech2134.txt
# Successfully cleaned and saved bctech2135.txt
# Successfully cleaned and saved bctech2136.txt
# Successfully cleaned and saved bctech2137.txt
# Successfully cleaned and saved bctech2138.txt
# Successfully cleaned and saved bctech2139.txt
# Successfully cleaned and saved bctech2140.txt
# Successfully cleaned and saved bctech2141.txt
# Successfully cleaned and saved bctech2142.txt
# Successfully cleaned and saved bctech2143.txt
# Successfully cleaned and saved bctech2144.txt
# Successfully cleaned and saved bctech2145.txt
# Successfully cleaned and saved bctech2146.txt
# Successfully cleaned and saved bctech2147.txt
# Successfully cleaned and saved bctech2148.txt
# Successfully cleaned and saved bctech2149.txt
# Successfully cleaned and saved bctech2150.txt
# Successfully cleaned and saved bctech2151.txt
# Successfully cleaned and saved bctech2152.txt
# Successfully cleaned and saved bctech2153.txt
# Successfully cleaned and saved bctech2154.txt
# Successfully cleaned and saved bctech2155.txt
# Successfully cleaned and saved bctech2156.txt
# Successfully cleaned and saved bctech2157.txt

# %% [markdown]
# ### Creating a dictionary of postive and neagative words from the 'MasterDictionary' folder

# %%
import os

# Function to load stop words from the StopWords folder
def load_stopwords(stopwords_dir):
    stop_words = set()
    for filename in os.listdir(stopwords_dir):
        if filename.endswith(".txt"):
            filepath = os.path.join(stopwords_dir, filename)
            with open(filepath, 'r', encoding='utf-8', errors='ignore') as file:
                words = file.read().splitlines()
                stop_words.update(words)
    return stop_words

# Function to load positive and negative words from the Master_Dictionary
def load_master_dictionary(master_dict_dir, stop_words):
    positive_words = set()
    negative_words = set()

    # Load positive words
    positive_file = os.path.join(master_dict_dir, 'positive-words.txt')
    with open(positive_file, 'r', encoding='utf-8', errors='ignore') as file:
        words = file.read().splitlines()
        # Add words to positive dictionary if not in stop words
        positive_words.update([word for word in words if word.lower() not in stop_words])

    # Load negative words
    negative_file = os.path.join(master_dict_dir, 'negative-words.txt')
    with open(negative_file, 'r', encoding='utf-8', errors='ignore') as file:
        words = file.read().splitlines()
        # Add words to negative dictionary if not in stop words
        negative_words.update([word for word in words if word.lower() not in stop_words])

    return positive_words, negative_words

# Load all stop words from the StopWords folder
stopwords_dir = 'StopWords'  # Replace with the actual path to the StopWords folder
stop_words = load_stopwords(stopwords_dir)

# Load the Master Dictionary and filter out stop words
master_dict_dir = 'Master_Dictionary'  # Replace with the actual path to the Master_Dictionary folder
positive_words, negative_words = load_master_dictionary(master_dict_dir, stop_words)

# Display the number of words loaded
print(f"Positive words loaded: {len(positive_words)}")
print(f"Negative words loaded: {len(negative_words)}")

# You can now use positive_words and negative_words in your sentiment analysis
# Out:
# Positive words loaded: 1988
# Negative words loaded: 4779

# %% [markdown]
# ### Converting the text into a list of tokens and using these tokens to calculate 4 variables namely 'Positive Score', 'Negative Score', 'Polarity Score', and 'Subjectivity Score'

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\abhin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
import os
from nltk.tokenize import word_tokenize

# Function to calculate derived variables
def calculate_scores(text, positive_words, negative_words):
    # Tokenize the text
    tokens = word_tokenize(text)

    # Initialize scores
    positive_score = 0
    negative_score = 0

    # Calculate positive and negative scores
    for word in tokens:
        lower_word = word.lower()  # Normalize to lowercase
        if lower_word in positive_words:
            positive_score += 1
        elif lower_word in negative_words:
            negative_score += 1

    # Calculate Polarity Score
    if positive_score + negative_score > 0:
        polarity_score = (positive_score - negative_score) / (positive_score + negative_score + 0.000001)
    else:
        polarity_score = 0  # Default to 0 if no positive or negative words

    # Calculate Subjectivity Score
    total_words = len(tokens)
    if total_words > 0:
        subjectivity_score = (positive_score + negative_score) / (total_words + 0.000001)
    else:
        subjectivity_score = 0  # Default to 0 if no words

    return positive_score, negative_score, polarity_score, subjectivity_score

# Directory containing the article .txt files
articles_dir = 'scraped_articles'  # Replace with the folder where you saved your articles

# Load the Master Dictionary (ensure this part is in your script before this section)
# ...

# Loop through all .txt files in the articles directory and calculate scores
for filename in os.listdir(articles_dir):
    if filename.endswith(".txt"):
        filepath = os.path.join(articles_dir, filename)

        # Read the cleaned content of the article
        with open(filepath, 'r', encoding='utf-8', errors='ignore') as file:
            cleaned_text = file.read()

        # Calculate scores
        positive_score, negative_score, polarity_score, subjectivity_score = calculate_scores(
            cleaned_text, positive_words, negative_words)

        # Output the scores
        print(f"Scores for {filename}:")
        print(f"Positive Score: {positive_score}")
        print(f"Negative Score: {negative_score}")
        print(f"Polarity Score: {polarity_score}")
        print(f"Subjectivity Score: {subjectivity_score}")
        print("\n")
# Out:
# Scores for bctech2011.txt:
# Positive Score: 40
# Negative Score: 11
# Polarity Score: 0.5686274398308345
# Subjectivity Score: 0.06367041190553008
#
#
# Scores for bctech2012.txt:
# Positive Score: 8
# Negative Score: 3
# Polarity Score: 0.4545454132231443
# Subjectivity Score: 0.038327525998858795
#
#
# Scores for bctech2013.txt:
# Positive Score: 9
# Negative Score: 3
# Polarity Score: 0.4999999583333368
# Subjectivity Score: 0.04225352097798056
#
#
# Scores for bctech2014.txt:
# Positive Score: 8
# Negative Score: 3
# Polarity Score: 0.4545454132231443
# Subjectivity Score: 0.03806228360532082
#
#
# Scores for bctech2015.txt:
# Positive Score: 9
# Negative Score: 3
# Polarity Score: 0.4999999583333368
# Subjectivity Score: 0.04166666652199074
#
#
# Scores for bctech2016.txt:
# Positive Score: 8
# Negative Score: 3
# Polarity Score: 0.4545454132231443
# Subjectivity Score: 0.03873239422981551
#
#
# Scores for bctech2017.txt:
# Positive Score: 8
# Negative Score: 3
# Polarity Score: 0.4545454132231443
# Subjectivity Score: 0.038327525998858795
#
#
# Scores for bctech2018.txt:
# Positive Score: 7
# Negative Score: 3
# Polarity Score: 0.39999996000000404
# Subjectivity Score: 0.034843205453508
#
#
# Scores for bctech2019.txt:
# Positive Score: 7
# Negative Score: 3
# Polarity Score: 0.39999996000000404
# Subjectivity Score: 0.03333333322222222
#
#
# Scores for bctech2020.txt:
# Positive Score: 8
# Negative Score: 3
# Polarity Score: 0.4545454132231443
# Subjectivity Score: 0.03793103435196195
#
#
# Scores for bctech2021.txt:
# Positive Score: 9
# Negative Score: 3
# Polarity Score: 0.4999999583333368
# Subjectivity Score: 0.041237113260353564
#
#
# Scores for bctech2022.txt:
# Positive Score: 24
# Negative Score: 7
# Polarity Score: 0.5483870790842877
# Subjectivity Score: 0.04447632705240125
#
#
# Scores for bctech2023.txt:
# Positive Score: 22
# Negative Score: 6
# Polarity Score: 0.5714285510204089
# Subjectivity Score: 0.05384615374260355
#
#
# Scores for bctech2024.txt:
# Positive Score: 10
# Negative Score: 6
# Polarity Score: 0.24999998437500096
# Subjectivity Score: 0.041025640920447075
#
#
# Scores for bctech2025.txt:
# Positive Score: 23
# Negative Score: 8
# Polarity Score: 0.4838709521331951
# Subjectivity Score: 0.04897314368250688
#
#
# Scores for bctech2026.txt:
# Positive Score: 37
# Negative Score: 6
# Polarity Score: 0.7209302157923206
# Subjectivity Score: 0.07107438004781094
#
#
# Scores for bctech2027.txt:
# Positive Score: 23
# Negative Score: 5
# Polarity Score: 0.64285711989796
# Subjectivity Score: 0.05035971213964081
#
#
# Scores for bctech2028.txt:
# Positive Score: 27
# Negative Score: 11
# Polarity Score: 0.4210526204986153
# Subjectivity Score: 0.05563689596539254
#
#
# Scores for bctech2029.txt:
# Positive Score: 37
# Negative Score: 11
# Polarity Score: 0.5416666553819447
# Subjectivity Score: 0.07986688838624478
#
#
# Scores for bctech2030.txt:
# Positive Score: 29
# Negative Score: 15
# Polarity Score: 0.3181818109504134
# Subjectivity Score: 0.06697108056777613
#
#
# Scores for bctech2031.txt:
# Positive Score: 28
# Negative Score: 7
# Polarity Score: 0.5999999828571434
# Subjectivity Score: 0.046728971900228344
#
#
# Scores for bctech2032.txt:
# Positive Score: 8
# Negative Score: 3
# Polarity Score: 0.4545454132231443
# Subjectivity Score: 0.027918781655028473
#
#
# Scores for bctech2033.txt:
# Positive Score: 15
# Negative Score: 10
# Polarity Score: 0.19999999200000032
# Subjectivity Score: 0.04578754570368582
#
#
# Scores for bctech2034.txt:
# Positive Score: 26
# Negative Score: 3
# Polarity Score: 0.7931034209274682
# Subjectivity Score: 0.06183368856751879
#
#
# Scores for bctech2035.txt:
# Positive Score: 19
# Negative Score: 9
# Polarity Score: 0.35714284438775556
# Subjectivity Score: 0.0539499035569366
#
#
# Scores for bctech2036.txt:
# Positive Score: 26
# Negative Score: 14
# Polarity Score: 0.2999999925000002
# Subjectivity Score: 0.06201550377982092
#
#
# Scores for bctech2037.txt:
# Positive Score: 23
# Negative Score: 18
# Polarity Score: 0.12195121653777521
# Subjectivity Score: 0.053664921395726546
#
#
# Scores for bctech2038.txt:
# Positive Score: 14
# Negative Score: 4
# Polarity Score: 0.5555555246913597
# Subjectivity Score: 0.04235294107681661
#
#
# Scores for bctech2039.txt:
# Positive Score: 10
# Negative Score: 4
# Polarity Score: 0.42857139795918586
# Subjectivity Score: 0.03703703693905546
#
#
# Scores for bctech2040.txt:
# Positive Score: 9
# Negative Score: 4
# Polarity Score: 0.3846153550295881
# Subjectivity Score: 0.038123167043627074
#
#
# Scores for bctech2041.txt:
# Positive Score: 9
# Negative Score: 4
# Polarity Score: 0.3846153550295881
# Subjectivity Score: 0.0486891383944227
#
#
# Scores for bctech2042.txt:
# Positive Score: 9
# Negative Score: 4
# Polarity Score: 0.3846153550295881
# Subjectivity Score: 0.041269841138825904
#
#
# Scores for bctech2043.txt:
# Positive Score: 10
# Negative Score: 4
# Polarity Score: 0.42857139795918586
# Subjectivity Score: 0.03381642503909076
#
#
# Scores for bctech2044.txt:
# Positive Score: 14
# Negative Score: 5
# Polarity Score: 0.47368418559556913
# Subjectivity Score: 0.030894308892854782
#
#
# Scores for bctech2045.txt:
# Positive Score: 10
# Negative Score: 4
# Polarity Score: 0.42857139795918586
# Subjectivity Score: 0.034739454008090684
#
#
# Scores for bctech2046.txt:
# Positive Score: 9
# Negative Score: 4
# Polarity Score: 0.3846153550295881
# Subjectivity Score: 0.039039038921804686
#
#
# Scores for bctech2047.txt:
# Positive Score: 11
# Negative Score: 5
# Polarity Score: 0.37499997656250145
# Subjectivity Score: 0.04050632901137638
#
#
# Scores for bctech2048.txt:
# Positive Score: 10
# Negative Score: 5
# Polarity Score: 0.3333333111111126
# Subjectivity Score: 0.04424778748009502
#
#
# Scores for bctech2049.txt:
# Positive Score: 13
# Negative Score: 7
# Polarity Score: 0.29999998500000075
# Subjectivity Score: 0.04319654418316081
#
#
# Scores for bctech2050.txt:
# Positive Score: 12
# Negative Score: 5
# Polarity Score: 0.4117646816609011
# Subjectivity Score: 0.044973544854567345
#
#
# Scores for bctech2051.txt:
# Positive Score: 15
# Negative Score: 5
# Polarity Score: 0.4999999750000012
# Subjectivity Score: 0.04376367605303353
#
#
# Scores for bctech2052.txt:
# Positive Score: 16
# Negative Score: 4
# Polarity Score: 0.5999999700000015
# Subjectivity Score: 0.05376344071568968
#
#
# Scores for bctech2053.txt:
# Positive Score: 10
# Negative Score: 4
# Polarity Score: 0.42857139795918586
# Subjectivity Score: 0.03211009166947227
#
#
# Scores for bctech2054.txt:
# Positive Score: 17
# Negative Score: 7
# Polarity Score: 0.41666664930555625
# Subjectivity Score: 0.05568445462718224
#
#
# Scores for bctech2055.txt:
# Positive Score: 22
# Negative Score: 11
# Polarity Score: 0.33333332323232356
# Subjectivity Score: 0.07173913027882797
#
#
# Scores for bctech2056.txt:
# Positive Score: 10
# Negative Score: 7
# Polarity Score: 0.17647057785467188
# Subjectivity Score: 0.036093418182391895
#
#
# Scores for bctech2057.txt:
# Positive Score: 10
# Negative Score: 5
# Polarity Score: 0.3333333111111126
# Subjectivity Score: 0.037878787783134374
#
#
# Scores for bctech2058.txt:
# Positive Score: 9
# Negative Score: 4
# Polarity Score: 0.3846153550295881
# Subjectivity Score: 0.04153354619318356
#
#
# Scores for bctech2059.txt:
# Positive Score: 10
# Negative Score: 6
# Polarity Score: 0.24999998437500096
# Subjectivity Score: 0.05555555536265432
#
#
# Scores for bctech2060.txt:
# Positive Score: 10
# Negative Score: 4
# Polarity Score: 0.42857139795918586
# Subjectivity Score: 0.04501607702567178
#
#
# Scores for bctech2061.txt:
# Positive Score: 12
# Negative Score: 5
# Polarity Score: 0.4117646816609011
# Subjectivity Score: 0.042183622724110116
#
#
# Scores for bctech2062.txt:
# Positive Score: 17
# Negative Score: 4
# Polarity Score: 0.6190475895691624
# Subjectivity Score: 0.04895104883694394
#
#
# Scores for bctech2063.txt:
# Positive Score: 9
# Negative Score: 5
# Polarity Score: 0.2857142653061239
# Subjectivity Score: 0.043478260734539566
#
#
# Scores for bctech2064.txt:
# Positive Score: 9
# Negative Score: 7
# Polarity Score: 0.12499999218750048
# Subjectivity Score: 0.037209302239048135
#
#
# Scores for bctech2065.txt:
# Positive Score: 14
# Negative Score: 7
# Polarity Score: 0.3333333174603182
# Subjectivity Score: 0.041999999916
#
#
# Scores for bctech2066.txt:
# Positive Score: 16
# Negative Score: 11
# Polarity Score: 0.18518517832647488
# Subjectivity Score: 0.0747922435601323
#
#
# Scores for bctech2067.txt:
# Positive Score: 18
# Negative Score: 7
# Polarity Score: 0.4399999824000007
# Subjectivity Score: 0.05617977515465219
#
#
# Scores for bctech2068.txt:
# Positive Score: 17
# Negative Score: 8
# Polarity Score: 0.35999998560000057
# Subjectivity Score: 0.05341880330466068
#
#
# Scores for bctech2069.txt:
# Positive Score: 11
# Negative Score: 8
# Polarity Score: 0.15789472853185638
# Subjectivity Score: 0.05688622737459213
#
#
# Scores for bctech2070.txt:
# Positive Score: 10
# Negative Score: 4
# Polarity Score: 0.42857139795918586
# Subjectivity Score: 0.04946996448950543
#
#
# Scores for bctech2071.txt:
# Positive Score: 10
# Negative Score: 7
# Polarity Score: 0.17647057785467188
# Subjectivity Score: 0.057627118448721634
#
#
# Scores for bctech2072.txt:
# Positive Score: 12
# Negative Score: 7
# Polarity Score: 0.26315788088642733
# Subjectivity Score: 0.06312292337832916
#
#
# Scores for bctech2073.txt:
# Positive Score: 11
# Negative Score: 4
# Polarity Score: 0.46666663555555765
# Subjectivity Score: 0.05136986283777444
#
#
# Scores for bctech2074.txt:
# Positive Score: 10
# Negative Score: 11
# Polarity Score: -0.04761904535147403
# Subjectivity Score: 0.06344410856965527
#
#
# Scores for bctech2075.txt:
# Positive Score: 17
# Negative Score: 5
# Polarity Score: 0.5454545206611581
# Subjectivity Score: 0.052132701298263744
#
#
# Scores for bctech2076.txt:
# Positive Score: 16
# Negative Score: 7
# Polarity Score: 0.39130433081285515
# Subjectivity Score: 0.05054945043835286
#
#
# Scores for bctech2077.txt:
# Positive Score: 13
# Negative Score: 8
# Polarity Score: 0.23809522675737013
# Subjectivity Score: 0.04565217381379962
#
#
# Scores for bctech2078.txt:
# Positive Score: 26
# Negative Score: 16
# Polarity Score: 0.238095232426304
# Subjectivity Score: 0.08251473461195534
#
#
# Scores for bctech2079.txt:
# Positive Score: 13
# Negative Score: 4
# Polarity Score: 0.5294117335640156
# Subjectivity Score: 0.03632478624716926
#
#
# Scores for bctech2080.txt:
# Positive Score: 17
# Negative Score: 3
# Polarity Score: 0.6999999650000017
# Subjectivity Score: 0.047961630580427746
#
#
# Scores for bctech2081.txt:
# Positive Score: 31
# Negative Score: 7
# Polarity Score: 0.6315789307479229
# Subjectivity Score: 0.050599200997870575
#
#
# Scores for bctech2082.txt:
# Positive Score: 10
# Negative Score: 5
# Polarity Score: 0.3333333111111126
# Subjectivity Score: 0.04032258053676726
#
#
# Scores for bctech2083.txt:
# Positive Score: 11
# Negative Score: 3
# Polarity Score: 0.5714285306122479
# Subjectivity Score: 0.03104212853427466
#
#
# Scores for bctech2084.txt:
# Positive Score: 8
# Negative Score: 4
# Polarity Score: 0.3333333055555579
# Subjectivity Score: 0.04444444427983539
#
#
# Scores for bctech2085.txt:
# Positive Score: 13
# Negative Score: 5
# Polarity Score: 0.4444444197530878
# Subjectivity Score: 0.04568527907186477
#
#
# Scores for bctech2086.txt:
# Positive Score: 11
# Negative Score: 5
# Polarity Score: 0.37499997656250145
# Subjectivity Score: 0.040100250526064536
#
#
# Scores for bctech2087.txt:
# Positive Score: 7
# Negative Score: 3
# Polarity Score: 0.39999996000000404
# Subjectivity Score: 0.03355704686725823
#
#
# Scores for bctech2088.txt:
# Positive Score: 8
# Negative Score: 10
# Polarity Score: -0.11111110493827195
# Subjectivity Score: 0.05405405389172957
#
#
# Scores for bctech2089.txt:
# Positive Score: 7
# Negative Score: 15
# Polarity Score: -0.36363634710743875
# Subjectivity Score: 0.05774278200067511
#
#
# Scores for bctech2090.txt:
# Positive Score: 8
# Negative Score: 3
# Polarity Score: 0.4545454132231443
# Subjectivity Score: 0.02600472807091081
#
#
# Scores for bctech2091.txt:
# Positive Score: 8
# Negative Score: 3
# Polarity Score: 0.4545454132231443
# Subjectivity Score: 0.04182509489800344
#
#
# Scores for bctech2092.txt:
# Positive Score: 15
# Negative Score: 4
# Polarity Score: 0.5789473379501401
# Subjectivity Score: 0.05775075970288523
#
#
# Scores for bctech2093.txt:
# Positive Score: 11
# Negative Score: 9
# Polarity Score: 0.09999999500000024
# Subjectivity Score: 0.049751243657335215
#
#
# Scores for bctech2094.txt:
# Positive Score: 16
# Negative Score: 6
# Polarity Score: 0.4545454338842984
# Subjectivity Score: 0.04835164824538099
#
#
# Scores for bctech2095.txt:
# Positive Score: 7
# Negative Score: 3
# Polarity Score: 0.39999996000000404
# Subjectivity Score: 0.026315789404432133
#
#
# Scores for bctech2096.txt:
# Positive Score: 9
# Negative Score: 3
# Polarity Score: 0.4999999583333368
# Subjectivity Score: 0.045112781785290296
#
#
# Scores for bctech2097.txt:
# Positive Score: 8
# Negative Score: 5
# Polarity Score: 0.23076921301775286
# Subjectivity Score: 0.039039038921804686
#
#
# Scores for bctech2098.txt:
# Positive Score: 9
# Negative Score: 5
# Polarity Score: 0.2857142653061239
# Subjectivity Score: 0.03684210516620499
#
#
# Scores for bctech2099.txt:
# Positive Score: 7
# Negative Score: 4
# Polarity Score: 0.2727272479338866
# Subjectivity Score: 0.03333333323232323
#
#
# Scores for bctech2100.txt:
# Positive Score: 13
# Negative Score: 4
# Polarity Score: 0.5294117335640156
# Subjectivity Score: 0.05841924378550088
#
#
# Scores for bctech2101.txt:
# Positive Score: 7
# Negative Score: 11
# Polarity Score: -0.2222222098765439
# Subjectivity Score: 0.05405405389172957
#
#
# Scores for bctech2102.txt:
# Positive Score: 23
# Negative Score: 5
# Polarity Score: 0.64285711989796
# Subjectivity Score: 0.03758389256700149
#
#
# Scores for bctech2103.txt:
# Positive Score: 23
# Negative Score: 4
# Polarity Score: 0.7037036776406045
# Subjectivity Score: 0.03663500673455223
#
#
# Scores for bctech2104.txt:
# Positive Score: 7
# Negative Score: 3
# Polarity Score: 0.39999996000000404
# Subjectivity Score: 0.03984063729147157
#
#
# Scores for bctech2105.txt:
# Positive Score: 10
# Negative Score: 6
# Polarity Score: 0.24999998437500096
# Subjectivity Score: 0.042780748548714574
#
#
# Scores for bctech2106.txt:
# Positive Score: 10
# Negative Score: 6
# Polarity Score: 0.24999998437500096
# Subjectivity Score: 0.051612903059313216
#
#
# Scores for bctech2107.txt:
# Positive Score: 9
# Negative Score: 8
# Polarity Score: 0.05882352595155729
# Subjectivity Score: 0.04521276583720009
#
#
# Scores for bctech2108.txt:
# Positive Score: 7
# Negative Score: 4
# Polarity Score: 0.2727272479338866
# Subjectivity Score: 0.03133903124974635
#
#
# Scores for bctech2109.txt:
# Positive Score: 13
# Negative Score: 5
# Polarity Score: 0.4444444197530878
# Subjectivity Score: 0.039130434697542536
#
#
# Scores for bctech2110.txt:
# Positive Score: 10
# Negative Score: 3
# Polarity Score: 0.5384614970414233
# Subjectivity Score: 0.0374639768372796
#
#
# Scores for bctech2111.txt:
# Positive Score: 10
# Negative Score: 6
# Polarity Score: 0.24999998437500096
# Subjectivity Score: 0.0399999999
#
#
# Scores for bctech2112.txt:
# Positive Score: 7
# Negative Score: 4
# Polarity Score: 0.2727272479338866
# Subjectivity Score: 0.03900709206025854
#
#
# Scores for bctech2113.txt:
# Positive Score: 9
# Negative Score: 5
# Polarity Score: 0.2857142653061239
# Subjectivity Score: 0.034398034313518344
#
#
# Scores for bctech2114.txt:
# Positive Score: 7
# Negative Score: 3
# Polarity Score: 0.39999996000000404
# Subjectivity Score: 0.044843049126264356
#
#
# Scores for bctech2115.txt:
# Positive Score: 24
# Negative Score: 6
# Polarity Score: 0.5999999800000007
# Subjectivity Score: 0.05084745754093651
#
#
# Scores for bctech2116.txt:
# Positive Score: 14
# Negative Score: 3
# Polarity Score: 0.6470587854671302
# Subjectivity Score: 0.038374717746332464
#
#
# Scores for bctech2117.txt:
# Positive Score: 7
# Negative Score: 5
# Polarity Score: 0.16666665277777895
# Subjectivity Score: 0.026666666607407408
#
#
# Scores for bctech2118.txt:
# Positive Score: 11
# Negative Score: 3
# Polarity Score: 0.5714285306122479
# Subjectivity Score: 0.04810996547041249
#
#
# Scores for bctech2119.txt:
# Positive Score: 15
# Negative Score: 7
# Polarity Score: 0.36363634710743875
# Subjectivity Score: 0.05527638177066236
#
#
# Scores for bctech2120.txt:
# Positive Score: 14
# Negative Score: 6
# Polarity Score: 0.399999980000001
# Subjectivity Score: 0.04889975538166319
#
#
# Scores for bctech2121.txt:
# Positive Score: 16
# Negative Score: 5
# Polarity Score: 0.5238094988662143
# Subjectivity Score: 0.040152963594353795
#
#
# Scores for bctech2122.txt:
# Positive Score: 12
# Negative Score: 5
# Polarity Score: 0.4117646816609011
# Subjectivity Score: 0.044619422455067136
#
#
# Scores for bctech2123.txt:
# Positive Score: 21
# Negative Score: 3
# Polarity Score: 0.7499999687500013
# Subjectivity Score: 0.05741626780522424
#
#
# Scores for bctech2124.txt:
# Positive Score: 7
# Negative Score: 3
# Polarity Score: 0.39999996000000404
# Subjectivity Score: 0.038314176098413116
#
#
# Scores for bctech2125.txt:
# Positive Score: 12
# Negative Score: 5
# Polarity Score: 0.4117646816609011
# Subjectivity Score: 0.051204819122877054
#
#
# Scores for bctech2126.txt:
# Positive Score: 7
# Negative Score: 5
# Polarity Score: 0.16666665277777895
# Subjectivity Score: 0.04026845624070988
#
#
# Scores for bctech2127.txt:
# Positive Score: 14
# Negative Score: 3
# Polarity Score: 0.6470587854671302
# Subjectivity Score: 0.0384615383745214
#
#
# Scores for bctech2128.txt:
# Positive Score: 7
# Negative Score: 3
# Polarity Score: 0.39999996000000404
# Subjectivity Score: 0.02544529255611885
#
#
# Scores for bctech2129.txt:
# Positive Score: 6
# Negative Score: 3
# Polarity Score: 0.33333329629630043
# Subjectivity Score: 0.0351562498626709
#
#
# Scores for bctech2130.txt:
# Positive Score: 9
# Negative Score: 3
# Polarity Score: 0.4999999583333368
# Subjectivity Score: 0.043165467470627814
#
#
# Scores for bctech2131.txt:
# Positive Score: 12
# Negative Score: 3
# Polarity Score: 0.5999999600000027
# Subjectivity Score: 0.05172413775267539
#
#
# Scores for bctech2132.txt:
# Positive Score: 9
# Negative Score: 5
# Polarity Score: 0.2857142653061239
# Subjectivity Score: 0.050724637497374506
#
#
# Scores for bctech2133.txt:
# Positive Score: 10
# Negative Score: 6
# Polarity Score: 0.24999998437500096
# Subjectivity Score: 0.05947955368223214
#
#
# Scores for bctech2134.txt:
# Positive Score: 9
# Negative Score: 4
# Polarity Score: 0.3846153550295881
# Subjectivity Score: 0.04999999980769231
#
#
# Scores for bctech2135.txt:
# Positive Score: 15
# Negative Score: 3
# Polarity Score: 0.6666666296296316
# Subjectivity Score: 0.04675324663180975
#
#
# Scores for bctech2136.txt:
# Positive Score: 7
# Negative Score: 3
# Polarity Score: 0.39999996000000404
# Subjectivity Score: 0.03300330022111122
#
#
# Scores for bctech2137.txt:
# Positive Score: 9
# Negative Score: 11
# Polarity Score: -0.09999999500000024
# Subjectivity Score: 0.042826552370821086
#
#
# Scores for bctech2138.txt:
# Positive Score: 16
# Negative Score: 6
# Polarity Score: 0.4545454338842984
# Subjectivity Score: 0.0643274851920249
#
#
# Scores for bctech2139.txt:
# Positive Score: 18
# Negative Score: 5
# Polarity Score: 0.5652173667296797
# Subjectivity Score: 0.05239179942507563
#
#
# Scores for bctech2140.txt:
# Positive Score: 15
# Negative Score: 6
# Polarity Score: 0.4285714081632663
# Subjectivity Score: 0.055408970830055485
#
#
# Scores for bctech2141.txt:
# Positive Score: 10
# Negative Score: 3
# Polarity Score: 0.5384614970414233
# Subjectivity Score: 0.03249999991875
#
#
# Scores for bctech2142.txt:
# Positive Score: 10
# Negative Score: 4
# Polarity Score: 0.42857139795918586
# Subjectivity Score: 0.03580562650689098
#
#
# Scores for bctech2143.txt:
# Positive Score: 8
# Negative Score: 3
# Polarity Score: 0.4545454132231443
# Subjectivity Score: 0.03583061877579603
#
#
# Scores for bctech2144.txt:
# Positive Score: 8
# Negative Score: 5
# Polarity Score: 0.23076921301775286
# Subjectivity Score: 0.04276315775406856
#
#
# Scores for bctech2145.txt:
# Positive Score: 10
# Negative Score: 3
# Polarity Score: 0.5384614970414233
# Subjectivity Score: 0.04377104362366652
#
#
# Scores for bctech2146.txt:
# Positive Score: 10
# Negative Score: 3
# Polarity Score: 0.5384614970414233
# Subjectivity Score: 0.04347826072415297
#
#
# Scores for bctech2147.txt:
# Positive Score: 9
# Negative Score: 3
# Polarity Score: 0.4999999583333368
# Subjectivity Score: 0.03986710950210263
#
#
# Scores for bctech2148.txt:
# Positive Score: 8
# Negative Score: 3
# Polarity Score: 0.4545454132231443
# Subjectivity Score: 0.03942652315617734
#
#
# Scores for bctech2149.txt:
# Positive Score: 9
# Negative Score: 3
# Polarity Score: 0.4999999583333368
# Subjectivity Score: 0.042704626182545814
#
#
# Scores for bctech2150.txt:
# Positive Score: 10
# Negative Score: 5
# Polarity Score: 0.3333333111111126
# Subjectivity Score: 0.04120879109558025
#
#
# Scores for bctech2151.txt:
# Positive Score: 20
# Negative Score: 13
# Polarity Score: 0.21212120569329682
# Subjectivity Score: 0.038777908297558276
#
#
# Scores for bctech2152.txt:
# Positive Score: 15
# Negative Score: 10
# Polarity Score: 0.19999999200000032
# Subjectivity Score: 0.04355400689276306
#
#
# Scores for bctech2153.txt:
# Positive Score: 19
# Negative Score: 12
# Polarity Score: 0.22580644432882438
# Subjectivity Score: 0.03690476186082767
#
#
# Scores for bctech2154.txt:
# Positive Score: 27
# Negative Score: 22
# Polarity Score: 0.10204081424406503
# Subjectivity Score: 0.04103852592877845
#
#
# Scores for bctech2155.txt:
# Positive Score: 12
# Negative Score: 10
# Polarity Score: 0.09090908677685969
# Subjectivity Score: 0.06358381484513348
#
#
# Scores for bctech2156.txt:
# Positive Score: 6
# Negative Score: 3
# Polarity Score: 0.33333329629630043
# Subjectivity Score: 0.04205607456983143
#
#
# Scores for bctech2157.txt:
# Positive Score: 8
# Negative Score: 3
# Polarity Score: 0.4545454132231443
# Subjectivity Score: 0.03956834518140883

# %% [markdown]
# ### Analysis of Readabitity, Complex Word count, Word Count, and Avg. no. of words per sentence

# %%
import os
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

# Ensure you have the necessary resources downloaded
nltk.download('punkt_tab')
nltk.download('stopwords')

# Function to calculate readability metrics
def readability_analysis(text):
    # Tokenize text into sentences and words
    sentences = sent_tokenize(text)
    words = word_tokenize(text)

    # Load stop words from NLTK
    stop_words = set(stopwords.words('english'))

    # Remove stop words and punctuation from words
    cleaned_words = [word for word in words if word.isalpha() and word.lower() not in stop_words]

    # Count total sentences and cleaned words
    total_sentences = len(sentences)
    total_words = len(cleaned_words)

    # Calculate Average Sentence Length
    if total_sentences > 0:
        average_sentence_length = total_words / total_sentences
    else:
        average_sentence_length = 0

    # Count complex words (more than 2 syllables)
    complex_word_count = sum(1 for word in cleaned_words if syllable_count(word) > 2)

    # Calculate Percentage of Complex Words
    if total_words > 0:
        percentage_complex_words = complex_word_count / total_words
    else:
        percentage_complex_words = 0

    # Calculate Fog Index
    fog_index = 0.4 * (average_sentence_length + percentage_complex_words)

    # Calculate Average Number of Words Per Sentence
    avg_words_per_sentence = total_words / total_sentences if total_sentences > 0 else 0

    return average_sentence_length, percentage_complex_words, fog_index, complex_word_count, total_words, avg_words_per_sentence

# Function to count syllables in a word
def syllable_count(word):
    word = word.lower()
    vowels = "aeiouy"
    count = 0
    is_prev_vowel = False

    for char in word:
        if char in vowels:
            if not is_prev_vowel:
                count += 1
                is_prev_vowel = True
        else:
            is_prev_vowel = False

    # Remove silent 'e' at the end
    if word.endswith("e"):
        count -= 1
    # Handle exceptions for "ed" and "es"
    if word.endswith("ed") or word.endswith("es"):
        count -= 1

    # Ensure count is at least 1
    return max(count, 1)

# Directory containing the article .txt files
articles_dir = 'scraped_articles'  # Replace with the folder where you saved your articles

# Loop through all .txt files in the articles directory and analyze each
for filename in os.listdir(articles_dir):
    if filename.endswith(".txt"):
        filepath = os.path.join(articles_dir, filename)

        # Read the content of the article
        with open(filepath, 'r', encoding='utf-8', errors='ignore') as file:
            article_text = file.read()

        # Analyze the text
        average_sentence_length, percentage_complex_words, fog_index, complex_word_count, word_count, avg_words_per_sentence = readability_analysis(article_text)

        # Output the results for each file
        print(f"Text Analysis Results for {filename}:")
        print(f"Average Sentence Length: {average_sentence_length:.2f}")
        print(f"Percentage of Complex Words: {percentage_complex_words * 100:.2f}%")
        print(f"Fog Index: {fog_index:.2f}")
        print(f"Complex Word Count: {complex_word_count}")
        print(f"Word Count (cleaned): {word_count}")
        print(f"Average Number of Words Per Sentence: {avg_words_per_sentence:.2f}")
        print("\n" + "-" * 40 + "\n")  # Separator for better readability
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\abhin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\abhin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Text Analysis Results for bctech2011.txt:
# Average Sentence Length: 26.48
# Percentage of Complex Words: 43.84%
# Fog Index: 10.77
# Complex Word Count: 267
# Word Count (cleaned): 609
# Average Number of Words Per Sentence: 26.48
#
# ----------------------------------------
#
# Text Analysis Results for bctech2012.txt:
# Average Sentence Length: 34.67
# Percentage of Complex Words: 37.02%
# Fog Index: 14.01
# Complex Word Count: 77
# Word Count (cleaned): 208
# Average Number of Words Per Sentence: 34.67
#
# ----------------------------------------
#
# Text Analysis Results for bctech2013.txt:
# Average Sentence Length: 34.33
# Percentage of Complex Words: 39.32%
# Fog Index: 13.89
# Complex Word Count: 81
# Word Count (cleaned): 206
# Average Number of Words Per Sentence: 34.33
#
# ----------------------------------------
#
# Text Analysis Results for bctech2014.txt:
# Average Sentence Length: 34.67
# Percentage of Complex Words: 38.46%
# Fog Index: 14.02
# Complex Word Count: 80
# Word Count (cleaned): 208
# Average Number of Words Per Sentence: 34.67
#
# ----------------------------------------
#
# Text Analysis Results for bctech2015.txt:
# Average Sentence Length: 34.67
# Percentage of Complex Words: 39.42%
# Fog Index: 14.02
# Complex Word Count: 82
# Word Count (cleaned): 208
# Average Number of Words Per Sentence: 34.67
#
# ----------------------------------------
#
# Text Analysis Results for bctech2016.txt:
# Average Sentence Length: 34.17
# Percentage of Complex Words: 39.51%
# Fog Index: 13.82
# Complex Word Count: 81
# Word Count (cleaned): 205
# Average Number of Words Per Sentence: 34.17
#
# ----------------------------------------
#
# Text Analysis Results for bctech2017.txt:
# Average Sentence Length: 34.83
# Percentage of Complex Words: 37.80%
# Fog Index: 14.08
# Complex Word Count: 79
# Word Count (cleaned): 209
# Average Number of Words Per Sentence: 34.83
#
# ----------------------------------------
#
# Text Analysis Results for bctech2018.txt:
# Average Sentence Length: 34.67
# Percentage of Complex Words: 38.46%
# Fog Index: 14.02
# Complex Word Count: 80
# Word Count (cleaned): 208
# Average Number of Words Per Sentence: 34.67
#
# ----------------------------------------
#
# Text Analysis Results for bctech2019.txt:
# Average Sentence Length: 36.17
# Percentage of Complex Words: 39.17%
# Fog Index: 14.62
# Complex Word Count: 85
# Word Count (cleaned): 217
# Average Number of Words Per Sentence: 36.17
#
# ----------------------------------------
#
# Text Analysis Results for bctech2020.txt:
# Average Sentence Length: 34.67
# Percentage of Complex Words: 39.42%
# Fog Index: 14.02
# Complex Word Count: 82
# Word Count (cleaned): 208
# Average Number of Words Per Sentence: 34.67
#
# ----------------------------------------
#
# Text Analysis Results for bctech2021.txt:
# Average Sentence Length: 35.33
# Percentage of Complex Words: 39.62%
# Fog Index: 14.29
# Complex Word Count: 84
# Word Count (cleaned): 212
# Average Number of Words Per Sentence: 35.33
#
# ----------------------------------------
#
# Text Analysis Results for bctech2022.txt:
# Average Sentence Length: 13.78
# Percentage of Complex Words: 33.73%
# Fog Index: 5.65
# Complex Word Count: 172
# Word Count (cleaned): 510
# Average Number of Words Per Sentence: 13.78
#
# ----------------------------------------
#
# Text Analysis Results for bctech2023.txt:
# Average Sentence Length: 19.35
# Percentage of Complex Words: 37.73%
# Fog Index: 7.89
# Complex Word Count: 146
# Word Count (cleaned): 387
# Average Number of Words Per Sentence: 19.35
#
# ----------------------------------------
#
# Text Analysis Results for bctech2024.txt:
# Average Sentence Length: 26.09
# Percentage of Complex Words: 35.19%
# Fog Index: 10.58
# Complex Word Count: 101
# Word Count (cleaned): 287
# Average Number of Words Per Sentence: 26.09
#
# ----------------------------------------
#
# Text Analysis Results for bctech2025.txt:
# Average Sentence Length: 14.48
# Percentage of Complex Words: 34.94%
# Fog Index: 5.93
# Complex Word Count: 167
# Word Count (cleaned): 478
# Average Number of Words Per Sentence: 14.48
#
# ----------------------------------------
#
# Text Analysis Results for bctech2026.txt:
# Average Sentence Length: 18.12
# Percentage of Complex Words: 35.10%
# Fog Index: 7.39
# Complex Word Count: 159
# Word Count (cleaned): 453
# Average Number of Words Per Sentence: 18.12
#
# ----------------------------------------
#
# Text Analysis Results for bctech2027.txt:
# Average Sentence Length: 16.80
# Percentage of Complex Words: 35.71%
# Fog Index: 6.86
# Complex Word Count: 150
# Word Count (cleaned): 420
# Average Number of Words Per Sentence: 16.80
#
# ----------------------------------------
#
# Text Analysis Results for bctech2028.txt:
# Average Sentence Length: 15.15
# Percentage of Complex Words: 32.43%
# Fog Index: 6.19
# Complex Word Count: 167
# Word Count (cleaned): 515
# Average Number of Words Per Sentence: 15.15
#
# ----------------------------------------
#
# Text Analysis Results for bctech2029.txt:
# Average Sentence Length: 16.74
# Percentage of Complex Words: 37.83%
# Fog Index: 6.85
# Complex Word Count: 171
# Word Count (cleaned): 452
# Average Number of Words Per Sentence: 16.74
#
# ----------------------------------------
#
# Text Analysis Results for bctech2030.txt:
# Average Sentence Length: 14.35
# Percentage of Complex Words: 33.81%
# Fog Index: 5.88
# Complex Word Count: 165
# Word Count (cleaned): 488
# Average Number of Words Per Sentence: 14.35
#
# ----------------------------------------
#
# Text Analysis Results for bctech2031.txt:
# Average Sentence Length: 12.93
# Percentage of Complex Words: 36.83%
# Fog Index: 5.32
# Complex Word Count: 200
# Word Count (cleaned): 543
# Average Number of Words Per Sentence: 12.93
#
# ----------------------------------------
#
# Text Analysis Results for bctech2032.txt:
# Average Sentence Length: 26.00
# Percentage of Complex Words: 33.57%
# Fog Index: 10.53
# Complex Word Count: 96
# Word Count (cleaned): 286
# Average Number of Words Per Sentence: 26.00
#
# ----------------------------------------
#
# Text Analysis Results for bctech2033.txt:
# Average Sentence Length: 15.54
# Percentage of Complex Words: 39.85%
# Fog Index: 6.37
# Complex Word Count: 161
# Word Count (cleaned): 404
# Average Number of Words Per Sentence: 15.54
#
# ----------------------------------------
#
# Text Analysis Results for bctech2034.txt:
# Average Sentence Length: 19.28
# Percentage of Complex Words: 36.60%
# Fog Index: 7.86
# Complex Word Count: 127
# Word Count (cleaned): 347
# Average Number of Words Per Sentence: 19.28
#
# ----------------------------------------
#
# Text Analysis Results for bctech2035.txt:
# Average Sentence Length: 14.81
# Percentage of Complex Words: 42.00%
# Fog Index: 6.09
# Complex Word Count: 168
# Word Count (cleaned): 400
# Average Number of Words Per Sentence: 14.81
#
# ----------------------------------------
#
# Text Analysis Results for bctech2036.txt:
# Average Sentence Length: 11.83
# Percentage of Complex Words: 36.22%
# Fog Index: 4.88
# Complex Word Count: 180
# Word Count (cleaned): 497
# Average Number of Words Per Sentence: 11.83
#
# ----------------------------------------
#
# Text Analysis Results for bctech2037.txt:
# Average Sentence Length: 20.93
# Percentage of Complex Words: 28.50%
# Fog Index: 8.49
# Complex Word Count: 173
# Word Count (cleaned): 607
# Average Number of Words Per Sentence: 20.93
#
# ----------------------------------------
#
# Text Analysis Results for bctech2038.txt:
# Average Sentence Length: 18.24
# Percentage of Complex Words: 26.77%
# Fog Index: 7.40
# Complex Word Count: 83
# Word Count (cleaned): 310
# Average Number of Words Per Sentence: 18.24
#
# ----------------------------------------
#
# Text Analysis Results for bctech2039.txt:
# Average Sentence Length: 17.44
# Percentage of Complex Words: 31.90%
# Fog Index: 7.10
# Complex Word Count: 89
# Word Count (cleaned): 279
# Average Number of Words Per Sentence: 17.44
#
# ----------------------------------------
#
# Text Analysis Results for bctech2040.txt:
# Average Sentence Length: 43.83
# Percentage of Complex Words: 31.56%
# Fog Index: 17.66
# Complex Word Count: 83
# Word Count (cleaned): 263
# Average Number of Words Per Sentence: 43.83
#
# ----------------------------------------
#
# Text Analysis Results for bctech2041.txt:
# Average Sentence Length: 33.33
# Percentage of Complex Words: 37.00%
# Fog Index: 13.48
# Complex Word Count: 74
# Word Count (cleaned): 200
# Average Number of Words Per Sentence: 33.33
#
# ----------------------------------------
#
# Text Analysis Results for bctech2042.txt:
# Average Sentence Length: 33.71
# Percentage of Complex Words: 33.47%
# Fog Index: 13.62
# Complex Word Count: 79
# Word Count (cleaned): 236
# Average Number of Words Per Sentence: 33.71
#
# ----------------------------------------
#
# Text Analysis Results for bctech2043.txt:
# Average Sentence Length: 42.43
# Percentage of Complex Words: 28.28%
# Fog Index: 17.08
# Complex Word Count: 84
# Word Count (cleaned): 297
# Average Number of Words Per Sentence: 42.43
#
# ----------------------------------------
#
# Text Analysis Results for bctech2044.txt:
# Average Sentence Length: 13.73
# Percentage of Complex Words: 31.93%
# Fog Index: 5.62
# Complex Word Count: 114
# Word Count (cleaned): 357
# Average Number of Words Per Sentence: 13.73
#
# ----------------------------------------
#
# Text Analysis Results for bctech2045.txt:
# Average Sentence Length: 18.44
# Percentage of Complex Words: 32.88%
# Fog Index: 7.51
# Complex Word Count: 97
# Word Count (cleaned): 295
# Average Number of Words Per Sentence: 18.44
#
# ----------------------------------------
#
# Text Analysis Results for bctech2046.txt:
# Average Sentence Length: 19.31
# Percentage of Complex Words: 32.67%
# Fog Index: 7.85
# Complex Word Count: 82
# Word Count (cleaned): 251
# Average Number of Words Per Sentence: 19.31
#
# ----------------------------------------
#
# Text Analysis Results for bctech2047.txt:
# Average Sentence Length: 32.89
# Percentage of Complex Words: 35.47%
# Fog Index: 13.30
# Complex Word Count: 105
# Word Count (cleaned): 296
# Average Number of Words Per Sentence: 32.89
#
# ----------------------------------------
#
# Text Analysis Results for bctech2048.txt:
# Average Sentence Length: 26.20
# Percentage of Complex Words: 32.82%
# Fog Index: 10.61
# Complex Word Count: 86
# Word Count (cleaned): 262
# Average Number of Words Per Sentence: 26.20
#
# ----------------------------------------
#
# Text Analysis Results for bctech2049.txt:
# Average Sentence Length: 19.00
# Percentage of Complex Words: 32.96%
# Fog Index: 7.73
# Complex Word Count: 119
# Word Count (cleaned): 361
# Average Number of Words Per Sentence: 19.00
#
# ----------------------------------------
#
# Text Analysis Results for bctech2050.txt:
# Average Sentence Length: 21.21
# Percentage of Complex Words: 33.67%
# Fog Index: 8.62
# Complex Word Count: 100
# Word Count (cleaned): 297
# Average Number of Words Per Sentence: 21.21
#
# ----------------------------------------
#
# Text Analysis Results for bctech2051.txt:
# Average Sentence Length: 26.38
# Percentage of Complex Words: 35.57%
# Fog Index: 10.70
# Complex Word Count: 122
# Word Count (cleaned): 343
# Average Number of Words Per Sentence: 26.38
#
# ----------------------------------------
#
# Text Analysis Results for bctech2052.txt:
# Average Sentence Length: 18.73
# Percentage of Complex Words: 32.03%
# Fog Index: 7.62
# Complex Word Count: 90
# Word Count (cleaned): 281
# Average Number of Words Per Sentence: 18.73
#
# ----------------------------------------
#
# Text Analysis Results for bctech2053.txt:
# Average Sentence Length: 20.60
# Percentage of Complex Words: 29.77%
# Fog Index: 8.36
# Complex Word Count: 92
# Word Count (cleaned): 309
# Average Number of Words Per Sentence: 20.60
#
# ----------------------------------------
#
# Text Analysis Results for bctech2054.txt:
# Average Sentence Length: 12.26
# Percentage of Complex Words: 29.00%
# Fog Index: 5.02
# Complex Word Count: 96
# Word Count (cleaned): 331
# Average Number of Words Per Sentence: 12.26
#
# ----------------------------------------
#
# Text Analysis Results for bctech2055.txt:
# Average Sentence Length: 11.47
# Percentage of Complex Words: 31.69%
# Fog Index: 4.71
# Complex Word Count: 109
# Word Count (cleaned): 344
# Average Number of Words Per Sentence: 11.47
#
# ----------------------------------------
#
# Text Analysis Results for bctech2056.txt:
# Average Sentence Length: 15.70
# Percentage of Complex Words: 34.35%
# Fog Index: 6.42
# Complex Word Count: 124
# Word Count (cleaned): 361
# Average Number of Words Per Sentence: 15.70
#
# ----------------------------------------
#
# Text Analysis Results for bctech2057.txt:
# Average Sentence Length: 23.00
# Percentage of Complex Words: 30.77%
# Fog Index: 9.32
# Complex Word Count: 92
# Word Count (cleaned): 299
# Average Number of Words Per Sentence: 23.00
#
# ----------------------------------------
#
# Text Analysis Results for bctech2058.txt:
# Average Sentence Length: 38.33
# Percentage of Complex Words: 33.91%
# Fog Index: 15.47
# Complex Word Count: 78
# Word Count (cleaned): 230
# Average Number of Words Per Sentence: 38.33
#
# ----------------------------------------
#
# Text Analysis Results for bctech2059.txt:
# Average Sentence Length: 23.67
# Percentage of Complex Words: 36.62%
# Fog Index: 9.61
# Complex Word Count: 78
# Word Count (cleaned): 213
# Average Number of Words Per Sentence: 23.67
#
# ----------------------------------------
#
# Text Analysis Results for bctech2060.txt:
# Average Sentence Length: 28.25
# Percentage of Complex Words: 38.50%
# Fog Index: 11.45
# Complex Word Count: 87
# Word Count (cleaned): 226
# Average Number of Words Per Sentence: 28.25
#
# ----------------------------------------
#
# Text Analysis Results for bctech2061.txt:
# Average Sentence Length: 24.00
# Percentage of Complex Words: 38.54%
# Fog Index: 9.75
# Complex Word Count: 111
# Word Count (cleaned): 288
# Average Number of Words Per Sentence: 24.00
#
# ----------------------------------------
#
# Text Analysis Results for bctech2062.txt:
# Average Sentence Length: 18.00
# Percentage of Complex Words: 31.79%
# Fog Index: 7.33
# Complex Word Count: 103
# Word Count (cleaned): 324
# Average Number of Words Per Sentence: 18.00
#
# ----------------------------------------
#
# Text Analysis Results for bctech2063.txt:
# Average Sentence Length: 23.40
# Percentage of Complex Words: 33.76%
# Fog Index: 9.50
# Complex Word Count: 79
# Word Count (cleaned): 234
# Average Number of Words Per Sentence: 23.40
#
# ----------------------------------------
#
# Text Analysis Results for bctech2064.txt:
# Average Sentence Length: 13.83
# Percentage of Complex Words: 35.84%
# Fog Index: 5.68
# Complex Word Count: 119
# Word Count (cleaned): 332
# Average Number of Words Per Sentence: 13.83
#
# ----------------------------------------
#
# Text Analysis Results for bctech2065.txt:
# Average Sentence Length: 21.12
# Percentage of Complex Words: 34.82%
# Fog Index: 8.59
# Complex Word Count: 125
# Word Count (cleaned): 359
# Average Number of Words Per Sentence: 21.12
#
# ----------------------------------------
#
# Text Analysis Results for bctech2066.txt:
# Average Sentence Length: 24.82
# Percentage of Complex Words: 35.53%
# Fog Index: 10.07
# Complex Word Count: 97
# Word Count (cleaned): 273
# Average Number of Words Per Sentence: 24.82
#
# ----------------------------------------
#
# Text Analysis Results for bctech2067.txt:
# Average Sentence Length: 18.67
# Percentage of Complex Words: 30.95%
# Fog Index: 7.59
# Complex Word Count: 104
# Word Count (cleaned): 336
# Average Number of Words Per Sentence: 18.67
#
# ----------------------------------------
#
# Text Analysis Results for bctech2068.txt:
# Average Sentence Length: 13.62
# Percentage of Complex Words: 32.49%
# Fog Index: 5.58
# Complex Word Count: 115
# Word Count (cleaned): 354
# Average Number of Words Per Sentence: 13.62
#
# ----------------------------------------
#
# Text Analysis Results for bctech2069.txt:
# Average Sentence Length: 17.79
# Percentage of Complex Words: 35.34%
# Fog Index: 7.26
# Complex Word Count: 88
# Word Count (cleaned): 249
# Average Number of Words Per Sentence: 17.79
#
# ----------------------------------------
#
# Text Analysis Results for bctech2070.txt:
# Average Sentence Length: 23.78
# Percentage of Complex Words: 35.51%
# Fog Index: 9.65
# Complex Word Count: 76
# Word Count (cleaned): 214
# Average Number of Words Per Sentence: 23.78
#
# ----------------------------------------
#
# Text Analysis Results for bctech2071.txt:
# Average Sentence Length: 24.89
# Percentage of Complex Words: 37.50%
# Fog Index: 10.11
# Complex Word Count: 84
# Word Count (cleaned): 224
# Average Number of Words Per Sentence: 24.89
#
# ----------------------------------------
#
# Text Analysis Results for bctech2072.txt:
# Average Sentence Length: 20.91
# Percentage of Complex Words: 37.39%
# Fog Index: 8.51
# Complex Word Count: 86
# Word Count (cleaned): 230
# Average Number of Words Per Sentence: 20.91
#
# ----------------------------------------
#
# Text Analysis Results for bctech2073.txt:
# Average Sentence Length: 24.56
# Percentage of Complex Words: 36.65%
# Fog Index: 9.97
# Complex Word Count: 81
# Word Count (cleaned): 221
# Average Number of Words Per Sentence: 24.56
#
# ----------------------------------------
#
# Text Analysis Results for bctech2074.txt:
# Average Sentence Length: 16.80
# Percentage of Complex Words: 38.10%
# Fog Index: 6.87
# Complex Word Count: 96
# Word Count (cleaned): 252
# Average Number of Words Per Sentence: 16.80
#
# ----------------------------------------
#
# Text Analysis Results for bctech2075.txt:
# Average Sentence Length: 15.19
# Percentage of Complex Words: 31.66%
# Fog Index: 6.20
# Complex Word Count: 101
# Word Count (cleaned): 319
# Average Number of Words Per Sentence: 15.19
#
# ----------------------------------------
#
# Text Analysis Results for bctech2076.txt:
# Average Sentence Length: 15.04
# Percentage of Complex Words: 35.55%
# Fog Index: 6.16
# Complex Word Count: 123
# Word Count (cleaned): 346
# Average Number of Words Per Sentence: 15.04
#
# ----------------------------------------
#
# Text Analysis Results for bctech2077.txt:
# Average Sentence Length: 18.45
# Percentage of Complex Words: 30.62%
# Fog Index: 7.50
# Complex Word Count: 113
# Word Count (cleaned): 369
# Average Number of Words Per Sentence: 18.45
#
# ----------------------------------------
#
# Text Analysis Results for bctech2078.txt:
# Average Sentence Length: 14.43
# Percentage of Complex Words: 28.96%
# Fog Index: 5.89
# Complex Word Count: 117
# Word Count (cleaned): 404
# Average Number of Words Per Sentence: 14.43
#
# ----------------------------------------
#
# Text Analysis Results for bctech2079.txt:
# Average Sentence Length: 16.41
# Percentage of Complex Words: 31.58%
# Fog Index: 6.69
# Complex Word Count: 114
# Word Count (cleaned): 361
# Average Number of Words Per Sentence: 16.41
#
# ----------------------------------------
#
# Text Analysis Results for bctech2080.txt:
# Average Sentence Length: 22.00
# Percentage of Complex Words: 33.64%
# Fog Index: 8.93
# Complex Word Count: 111
# Word Count (cleaned): 330
# Average Number of Words Per Sentence: 22.00
#
# ----------------------------------------
#
# Text Analysis Results for bctech2081.txt:
# Average Sentence Length: 16.03
# Percentage of Complex Words: 37.10%
# Fog Index: 6.56
# Complex Word Count: 220
# Word Count (cleaned): 593
# Average Number of Words Per Sentence: 16.03
#
# ----------------------------------------
#
# Text Analysis Results for bctech2082.txt:
# Average Sentence Length: 31.89
# Percentage of Complex Words: 32.06%
# Fog Index: 12.88
# Complex Word Count: 92
# Word Count (cleaned): 287
# Average Number of Words Per Sentence: 31.89
#
# ----------------------------------------
#
# Text Analysis Results for bctech2083.txt:
# Average Sentence Length: 18.11
# Percentage of Complex Words: 35.47%
# Fog Index: 7.38
# Complex Word Count: 122
# Word Count (cleaned): 344
# Average Number of Words Per Sentence: 18.11
#
# ----------------------------------------
#
# Text Analysis Results for bctech2084.txt:
# Average Sentence Length: 40.80
# Percentage of Complex Words: 35.29%
# Fog Index: 16.46
# Complex Word Count: 72
# Word Count (cleaned): 204
# Average Number of Words Per Sentence: 40.80
#
# ----------------------------------------
#
# Text Analysis Results for bctech2085.txt:
# Average Sentence Length: 18.29
# Percentage of Complex Words: 34.41%
# Fog Index: 7.46
# Complex Word Count: 107
# Word Count (cleaned): 311
# Average Number of Words Per Sentence: 18.29
#
# ----------------------------------------
#
# Text Analysis Results for bctech2086.txt:
# Average Sentence Length: 20.67
# Percentage of Complex Words: 32.58%
# Fog Index: 8.40
# Complex Word Count: 101
# Word Count (cleaned): 310
# Average Number of Words Per Sentence: 20.67
#
# ----------------------------------------
#
# Text Analysis Results for bctech2087.txt:
# Average Sentence Length: 32.43
# Percentage of Complex Words: 37.44%
# Fog Index: 13.12
# Complex Word Count: 85
# Word Count (cleaned): 227
# Average Number of Words Per Sentence: 32.43
#
# ----------------------------------------
#
# Text Analysis Results for bctech2088.txt:
# Average Sentence Length: 21.42
# Percentage of Complex Words: 39.30%
# Fog Index: 8.72
# Complex Word Count: 101
# Word Count (cleaned): 257
# Average Number of Words Per Sentence: 21.42
#
# ----------------------------------------
#
# Text Analysis Results for bctech2089.txt:
# Average Sentence Length: 20.00
# Percentage of Complex Words: 28.00%
# Fog Index: 8.11
# Complex Word Count: 84
# Word Count (cleaned): 300
# Average Number of Words Per Sentence: 20.00
#
# ----------------------------------------
#
# Text Analysis Results for bctech2090.txt:
# Average Sentence Length: 32.50
# Percentage of Complex Words: 34.15%
# Fog Index: 13.14
# Complex Word Count: 111
# Word Count (cleaned): 325
# Average Number of Words Per Sentence: 32.50
#
# ----------------------------------------
#
# Text Analysis Results for bctech2091.txt:
# Average Sentence Length: 33.50
# Percentage of Complex Words: 36.32%
# Fog Index: 13.55
# Complex Word Count: 73
# Word Count (cleaned): 201
# Average Number of Words Per Sentence: 33.50
#
# ----------------------------------------
#
# Text Analysis Results for bctech2092.txt:
# Average Sentence Length: 36.29
# Percentage of Complex Words: 34.25%
# Fog Index: 14.65
# Complex Word Count: 87
# Word Count (cleaned): 254
# Average Number of Words Per Sentence: 36.29
#
# ----------------------------------------
#
# Text Analysis Results for bctech2093.txt:
# Average Sentence Length: 16.89
# Percentage of Complex Words: 31.91%
# Fog Index: 6.88
# Complex Word Count: 97
# Word Count (cleaned): 304
# Average Number of Words Per Sentence: 16.89
#
# ----------------------------------------
#
# Text Analysis Results for bctech2094.txt:
# Average Sentence Length: 20.12
# Percentage of Complex Words: 29.53%
# Fog Index: 8.17
# Complex Word Count: 101
# Word Count (cleaned): 342
# Average Number of Words Per Sentence: 20.12
#
# ----------------------------------------
#
# Text Analysis Results for bctech2095.txt:
# Average Sentence Length: 25.73
# Percentage of Complex Words: 30.74%
# Fog Index: 10.41
# Complex Word Count: 87
# Word Count (cleaned): 283
# Average Number of Words Per Sentence: 25.73
#
# ----------------------------------------
#
# Text Analysis Results for bctech2096.txt:
# Average Sentence Length: 42.80
# Percentage of Complex Words: 35.51%
# Fog Index: 17.26
# Complex Word Count: 76
# Word Count (cleaned): 214
# Average Number of Words Per Sentence: 42.80
#
# ----------------------------------------
#
# Text Analysis Results for bctech2097.txt:
# Average Sentence Length: 19.62
# Percentage of Complex Words: 36.08%
# Fog Index: 7.99
# Complex Word Count: 92
# Word Count (cleaned): 255
# Average Number of Words Per Sentence: 19.62
#
# ----------------------------------------
#
# Text Analysis Results for bctech2098.txt:
# Average Sentence Length: 17.53
# Percentage of Complex Words: 36.58%
# Fog Index: 7.16
# Complex Word Count: 109
# Word Count (cleaned): 298
# Average Number of Words Per Sentence: 17.53
#
# ----------------------------------------
#
# Text Analysis Results for bctech2099.txt:
# Average Sentence Length: 18.79
# Percentage of Complex Words: 33.08%
# Fog Index: 7.65
# Complex Word Count: 87
# Word Count (cleaned): 263
# Average Number of Words Per Sentence: 18.79
#
# ----------------------------------------
#
# Text Analysis Results for bctech2100.txt:
# Average Sentence Length: 47.80
# Percentage of Complex Words: 29.71%
# Fog Index: 19.24
# Complex Word Count: 71
# Word Count (cleaned): 239
# Average Number of Words Per Sentence: 47.80
#
# ----------------------------------------
#
# Text Analysis Results for bctech2101.txt:
# Average Sentence Length: 46.00
# Percentage of Complex Words: 30.43%
# Fog Index: 18.52
# Complex Word Count: 84
# Word Count (cleaned): 276
# Average Number of Words Per Sentence: 46.00
#
# ----------------------------------------
#
# Text Analysis Results for bctech2102.txt:
# Average Sentence Length: 16.47
# Percentage of Complex Words: 35.18%
# Fog Index: 6.73
# Complex Word Count: 197
# Word Count (cleaned): 560
# Average Number of Words Per Sentence: 16.47
#
# ----------------------------------------
#
# Text Analysis Results for bctech2103.txt:
# Average Sentence Length: 16.00
# Percentage of Complex Words: 31.77%
# Fog Index: 6.53
# Complex Word Count: 183
# Word Count (cleaned): 576
# Average Number of Words Per Sentence: 16.00
#
# ----------------------------------------
#
# Text Analysis Results for bctech2104.txt:
# Average Sentence Length: 32.83
# Percentage of Complex Words: 38.07%
# Fog Index: 13.29
# Complex Word Count: 75
# Word Count (cleaned): 197
# Average Number of Words Per Sentence: 32.83
#
# ----------------------------------------
#
# Text Analysis Results for bctech2105.txt:
# Average Sentence Length: 16.28
# Percentage of Complex Words: 30.03%
# Fog Index: 6.63
# Complex Word Count: 88
# Word Count (cleaned): 293
# Average Number of Words Per Sentence: 16.28
#
# ----------------------------------------
#
# Text Analysis Results for bctech2106.txt:
# Average Sentence Length: 22.64
# Percentage of Complex Words: 33.73%
# Fog Index: 9.19
# Complex Word Count: 84
# Word Count (cleaned): 249
# Average Number of Words Per Sentence: 22.64
#
# ----------------------------------------
#
# Text Analysis Results for bctech2107.txt:
# Average Sentence Length: 20.07
# Percentage of Complex Words: 28.57%
# Fog Index: 8.14
# Complex Word Count: 86
# Word Count (cleaned): 301
# Average Number of Words Per Sentence: 20.07
#
# ----------------------------------------
#
# Text Analysis Results for bctech2108.txt:
# Average Sentence Length: 22.83
# Percentage of Complex Words: 36.13%
# Fog Index: 9.28
# Complex Word Count: 99
# Word Count (cleaned): 274
# Average Number of Words Per Sentence: 22.83
#
# ----------------------------------------
#
# Text Analysis Results for bctech2109.txt:
# Average Sentence Length: 20.18
# Percentage of Complex Words: 36.15%
# Fog Index: 8.22
# Complex Word Count: 124
# Word Count (cleaned): 343
# Average Number of Words Per Sentence: 20.18
#
# ----------------------------------------
#
# Text Analysis Results for bctech2110.txt:
# Average Sentence Length: 15.00
# Percentage of Complex Words: 32.96%
# Fog Index: 6.13
# Complex Word Count: 89
# Word Count (cleaned): 270
# Average Number of Words Per Sentence: 15.00
#
# ----------------------------------------
#
# Text Analysis Results for bctech2111.txt:
# Average Sentence Length: 16.37
# Percentage of Complex Words: 30.55%
# Fog Index: 6.67
# Complex Word Count: 95
# Word Count (cleaned): 311
# Average Number of Words Per Sentence: 16.37
#
# ----------------------------------------
#
# Text Analysis Results for bctech2112.txt:
# Average Sentence Length: 26.88
# Percentage of Complex Words: 34.88%
# Fog Index: 10.89
# Complex Word Count: 75
# Word Count (cleaned): 215
# Average Number of Words Per Sentence: 26.88
#
# ----------------------------------------
#
# Text Analysis Results for bctech2113.txt:
# Average Sentence Length: 20.60
# Percentage of Complex Words: 34.30%
# Fog Index: 8.38
# Complex Word Count: 106
# Word Count (cleaned): 309
# Average Number of Words Per Sentence: 20.60
#
# ----------------------------------------
#
# Text Analysis Results for bctech2114.txt:
# Average Sentence Length: 43.50
# Percentage of Complex Words: 38.51%
# Fog Index: 17.55
# Complex Word Count: 67
# Word Count (cleaned): 174
# Average Number of Words Per Sentence: 43.50
#
# ----------------------------------------
#
# Text Analysis Results for bctech2115.txt:
# Average Sentence Length: 14.15
# Percentage of Complex Words: 29.12%
# Fog Index: 5.78
# Complex Word Count: 136
# Word Count (cleaned): 467
# Average Number of Words Per Sentence: 14.15
#
# ----------------------------------------
#
# Text Analysis Results for bctech2116.txt:
# Average Sentence Length: 18.28
# Percentage of Complex Words: 27.36%
# Fog Index: 7.42
# Complex Word Count: 90
# Word Count (cleaned): 329
# Average Number of Words Per Sentence: 18.28
#
# ----------------------------------------
#
# Text Analysis Results for bctech2117.txt:
# Average Sentence Length: 17.00
# Percentage of Complex Words: 33.44%
# Fog Index: 6.93
# Complex Word Count: 108
# Word Count (cleaned): 323
# Average Number of Words Per Sentence: 17.00
#
# ----------------------------------------
#
# Text Analysis Results for bctech2118.txt:
# Average Sentence Length: 26.00
# Percentage of Complex Words: 35.47%
# Fog Index: 10.54
# Complex Word Count: 83
# Word Count (cleaned): 234
# Average Number of Words Per Sentence: 26.00
#
# ----------------------------------------
#
# Text Analysis Results for bctech2119.txt:
# Average Sentence Length: 13.13
# Percentage of Complex Words: 28.48%
# Fog Index: 5.37
# Complex Word Count: 86
# Word Count (cleaned): 302
# Average Number of Words Per Sentence: 13.13
#
# ----------------------------------------
#
# Text Analysis Results for bctech2120.txt:
# Average Sentence Length: 23.00
# Percentage of Complex Words: 30.43%
# Fog Index: 9.32
# Complex Word Count: 98
# Word Count (cleaned): 322
# Average Number of Words Per Sentence: 23.00
#
# ----------------------------------------
#
# Text Analysis Results for bctech2121.txt:
# Average Sentence Length: 21.63
# Percentage of Complex Words: 27.25%
# Fog Index: 8.76
# Complex Word Count: 112
# Word Count (cleaned): 411
# Average Number of Words Per Sentence: 21.63
#
# ----------------------------------------
#
# Text Analysis Results for bctech2122.txt:
# Average Sentence Length: 19.47
# Percentage of Complex Words: 30.82%
# Fog Index: 7.91
# Complex Word Count: 90
# Word Count (cleaned): 292
# Average Number of Words Per Sentence: 19.47
#
# ----------------------------------------
#
# Text Analysis Results for bctech2123.txt:
# Average Sentence Length: 29.00
# Percentage of Complex Words: 31.35%
# Fog Index: 11.73
# Complex Word Count: 100
# Word Count (cleaned): 319
# Average Number of Words Per Sentence: 29.00
#
# ----------------------------------------
#
# Text Analysis Results for bctech2124.txt:
# Average Sentence Length: 32.83
# Percentage of Complex Words: 36.55%
# Fog Index: 13.28
# Complex Word Count: 72
# Word Count (cleaned): 197
# Average Number of Words Per Sentence: 32.83
#
# ----------------------------------------
#
# Text Analysis Results for bctech2125.txt:
# Average Sentence Length: 18.57
# Percentage of Complex Words: 36.92%
# Fog Index: 7.58
# Complex Word Count: 96
# Word Count (cleaned): 260
# Average Number of Words Per Sentence: 18.57
#
# ----------------------------------------
#
# Text Analysis Results for bctech2126.txt:
# Average Sentence Length: 32.71
# Percentage of Complex Words: 31.44%
# Fog Index: 13.21
# Complex Word Count: 72
# Word Count (cleaned): 229
# Average Number of Words Per Sentence: 32.71
#
# ----------------------------------------
#
# Text Analysis Results for bctech2127.txt:
# Average Sentence Length: 23.57
# Percentage of Complex Words: 31.21%
# Fog Index: 9.55
# Complex Word Count: 103
# Word Count (cleaned): 330
# Average Number of Words Per Sentence: 23.57
#
# ----------------------------------------
#
# Text Analysis Results for bctech2128.txt:
# Average Sentence Length: 16.39
# Percentage of Complex Words: 32.20%
# Fog Index: 6.68
# Complex Word Count: 95
# Word Count (cleaned): 295
# Average Number of Words Per Sentence: 16.39
#
# ----------------------------------------
#
# Text Analysis Results for bctech2129.txt:
# Average Sentence Length: 44.25
# Percentage of Complex Words: 36.72%
# Fog Index: 17.85
# Complex Word Count: 65
# Word Count (cleaned): 177
# Average Number of Words Per Sentence: 44.25
#
# ----------------------------------------
#
# Text Analysis Results for bctech2130.txt:
# Average Sentence Length: 24.33
# Percentage of Complex Words: 36.07%
# Fog Index: 9.88
# Complex Word Count: 79
# Word Count (cleaned): 219
# Average Number of Words Per Sentence: 24.33
#
# ----------------------------------------
#
# Text Analysis Results for bctech2131.txt:
# Average Sentence Length: 24.78
# Percentage of Complex Words: 37.22%
# Fog Index: 10.06
# Complex Word Count: 83
# Word Count (cleaned): 223
# Average Number of Words Per Sentence: 24.78
#
# ----------------------------------------
#
# Text Analysis Results for bctech2132.txt:
# Average Sentence Length: 41.00
# Percentage of Complex Words: 35.12%
# Fog Index: 16.54
# Complex Word Count: 72
# Word Count (cleaned): 205
# Average Number of Words Per Sentence: 41.00
#
# ----------------------------------------
#
# Text Analysis Results for bctech2133.txt:
# Average Sentence Length: 20.90
# Percentage of Complex Words: 37.32%
# Fog Index: 8.51
# Complex Word Count: 78
# Word Count (cleaned): 209
# Average Number of Words Per Sentence: 20.90
#
# ----------------------------------------
#
# Text Analysis Results for bctech2134.txt:
# Average Sentence Length: 22.78
# Percentage of Complex Words: 35.12%
# Fog Index: 9.25
# Complex Word Count: 72
# Word Count (cleaned): 205
# Average Number of Words Per Sentence: 22.78
#
# ----------------------------------------
#
# Text Analysis Results for bctech2135.txt:
# Average Sentence Length: 18.62
# Percentage of Complex Words: 32.89%
# Fog Index: 7.58
# Complex Word Count: 98
# Word Count (cleaned): 298
# Average Number of Words Per Sentence: 18.62
#
# ----------------------------------------
#
# Text Analysis Results for bctech2136.txt:
# Average Sentence Length: 23.10
# Percentage of Complex Words: 33.77%
# Fog Index: 9.38
# Complex Word Count: 78
# Word Count (cleaned): 231
# Average Number of Words Per Sentence: 23.10
#
# ----------------------------------------
#
# Text Analysis Results for bctech2137.txt:
# Average Sentence Length: 21.33
# Percentage of Complex Words: 32.55%
# Fog Index: 8.66
# Complex Word Count: 125
# Word Count (cleaned): 384
# Average Number of Words Per Sentence: 21.33
#
# ----------------------------------------
#
# Text Analysis Results for bctech2138.txt:
# Average Sentence Length: 21.00
# Percentage of Complex Words: 32.97%
# Fog Index: 8.53
# Complex Word Count: 90
# Word Count (cleaned): 273
# Average Number of Words Per Sentence: 21.00
#
# ----------------------------------------
#
# Text Analysis Results for bctech2139.txt:
# Average Sentence Length: 15.50
# Percentage of Complex Words: 36.36%
# Fog Index: 6.35
# Complex Word Count: 124
# Word Count (cleaned): 341
# Average Number of Words Per Sentence: 15.50
#
# ----------------------------------------
#
# Text Analysis Results for bctech2140.txt:
# Average Sentence Length: 18.62
# Percentage of Complex Words: 33.56%
# Fog Index: 7.58
# Complex Word Count: 100
# Word Count (cleaned): 298
# Average Number of Words Per Sentence: 18.62
#
# ----------------------------------------
#
# Text Analysis Results for bctech2141.txt:
# Average Sentence Length: 18.41
# Percentage of Complex Words: 34.19%
# Fog Index: 7.50
# Complex Word Count: 107
# Word Count (cleaned): 313
# Average Number of Words Per Sentence: 18.41
#
# ----------------------------------------
#
# Text Analysis Results for bctech2142.txt:
# Average Sentence Length: 19.38
# Percentage of Complex Words: 33.23%
# Fog Index: 7.88
# Complex Word Count: 103
# Word Count (cleaned): 310
# Average Number of Words Per Sentence: 19.38
#
# ----------------------------------------
#
# Text Analysis Results for bctech2143.txt:
# Average Sentence Length: 22.55
# Percentage of Complex Words: 35.48%
# Fog Index: 9.16
# Complex Word Count: 88
# Word Count (cleaned): 248
# Average Number of Words Per Sentence: 22.55
#
# ----------------------------------------
#
# Text Analysis Results for bctech2144.txt:
# Average Sentence Length: 35.43
# Percentage of Complex Words: 31.05%
# Fog Index: 14.30
# Complex Word Count: 77
# Word Count (cleaned): 248
# Average Number of Words Per Sentence: 35.43
#
# ----------------------------------------
#
# Text Analysis Results for bctech2145.txt:
# Average Sentence Length: 23.90
# Percentage of Complex Words: 37.24%
# Fog Index: 9.71
# Complex Word Count: 89
# Word Count (cleaned): 239
# Average Number of Words Per Sentence: 23.90
#
# ----------------------------------------
#
# Text Analysis Results for bctech2146.txt:
# Average Sentence Length: 27.22
# Percentage of Complex Words: 35.51%
# Fog Index: 11.03
# Complex Word Count: 87
# Word Count (cleaned): 245
# Average Number of Words Per Sentence: 27.22
#
# ----------------------------------------
#
# Text Analysis Results for bctech2147.txt:
# Average Sentence Length: 21.73
# Percentage of Complex Words: 35.56%
# Fog Index: 8.83
# Complex Word Count: 85
# Word Count (cleaned): 239
# Average Number of Words Per Sentence: 21.73
#
# ----------------------------------------
#
# Text Analysis Results for bctech2148.txt:
# Average Sentence Length: 32.14
# Percentage of Complex Words: 36.44%
# Fog Index: 13.00
# Complex Word Count: 82
# Word Count (cleaned): 225
# Average Number of Words Per Sentence: 32.14
#
# ----------------------------------------
#
# Text Analysis Results for bctech2149.txt:
# Average Sentence Length: 28.25
# Percentage of Complex Words: 37.17%
# Fog Index: 11.45
# Complex Word Count: 84
# Word Count (cleaned): 226
# Average Number of Words Per Sentence: 28.25
#
# ----------------------------------------
#
# Text Analysis Results for bctech2150.txt:
# Average Sentence Length: 17.79
# Percentage of Complex Words: 33.73%
# Fog Index: 7.25
# Complex Word Count: 84
# Word Count (cleaned): 249
# Average Number of Words Per Sentence: 17.79
#
# ----------------------------------------
#
# Text Analysis Results for bctech2151.txt:
# Average Sentence Length: 12.92
# Percentage of Complex Words: 27.47%
# Fog Index: 5.28
# Complex Word Count: 181
# Word Count (cleaned): 659
# Average Number of Words Per Sentence: 12.92
#
# ----------------------------------------
#
# Text Analysis Results for bctech2152.txt:
# Average Sentence Length: 17.83
# Percentage of Complex Words: 39.02%
# Fog Index: 7.29
# Complex Word Count: 167
# Word Count (cleaned): 428
# Average Number of Words Per Sentence: 17.83
#
# ----------------------------------------
#
# Text Analysis Results for bctech2153.txt:
# Average Sentence Length: 17.43
# Percentage of Complex Words: 33.64%
# Fog Index: 7.11
# Complex Word Count: 217
# Word Count (cleaned): 645
# Average Number of Words Per Sentence: 17.43
#
# ----------------------------------------
#
# Text Analysis Results for bctech2154.txt:
# Average Sentence Length: 13.90
# Percentage of Complex Words: 26.88%
# Fog Index: 5.67
# Complex Word Count: 254
# Word Count (cleaned): 945
# Average Number of Words Per Sentence: 13.90
#
# ----------------------------------------
#
# Text Analysis Results for bctech2155.txt:
# Average Sentence Length: 18.36
# Percentage of Complex Words: 31.52%
# Fog Index: 7.47
# Complex Word Count: 81
# Word Count (cleaned): 257
# Average Number of Words Per Sentence: 18.36
#
# ----------------------------------------
#
# Text Analysis Results for bctech2156.txt:
# Average Sentence Length: 42.75
# Percentage of Complex Words: 39.77%
# Fog Index: 17.26
# Complex Word Count: 68
# Word Count (cleaned): 171
# Average Number of Words Per Sentence: 42.75
#
# ----------------------------------------
#
# Text Analysis Results for bctech2157.txt:
# Average Sentence Length: 22.10
# Percentage of Complex Words: 36.65%
# Fog Index: 8.99
# Complex Word Count: 81
# Word Count (cleaned): 221
# Average Number of Words Per Sentence: 22.10
#
# ----------------------------------------

# %% [markdown]
# ### Calculating other variables like Total Syllables, Pronoun Count, and Average Word Length

# %%
import os
import nltk
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Ensure you have the necessary resources downloaded
nltk.download('punkt_tab')
nltk.download('stopwords')

# Function to count syllables in a word
def syllable_count(word):
    word = word.lower()
    vowels = "aeiouy"
    count = 0
    is_prev_vowel = False

    for char in word:
        if char in vowels:
            if not is_prev_vowel:
                count += 1
                is_prev_vowel = True
        else:
            is_prev_vowel = False

    # Remove silent 'e' at the end
    if word.endswith("e"):
        count -= 1
    # Handle exceptions for "ed" and "es"
    if word.endswith("ed") or word.endswith("es"):
        count -= 1

    # Ensure count is at least 1
    return max(count, 1)

# Function to count personal pronouns
def count_pronouns(text):
    # Define a regex pattern for the personal pronouns
    pronouns_pattern = r'\b(I|we|my|ours|us)\b'
    # Find all matches in the text
    matches = re.findall(pronouns_pattern, text, flags=re.IGNORECASE)
    return len(matches)

# Function to calculate average word length
def average_word_length(words):
    if not words:
        return 0
    # Calculate total characters in all words
    total_characters = sum(len(word) for word in words)
    return total_characters / len(words)

# Function to analyze text
def analyze_text(text):
    # Tokenize text into words
    words = word_tokenize(text)
    
    # Load English stop words
    stop_words = set(stopwords.words('english'))

    # Remove stop words and punctuation
    cleaned_words = [word for word in words if word.isalpha() and word.lower() not in stop_words]
    
    # Count syllables for each cleaned word
    syllable_counts = [syllable_count(word) for word in cleaned_words]

    # Count personal pronouns
    pronoun_count = count_pronouns(text)

    # Calculate average word length
    avg_word_length = average_word_length(cleaned_words)

    # Summary
    total_syllables = sum(syllable_counts)

    return {
        "Total Syllables": total_syllables,
        "Pronoun Count": pronoun_count,
        "Average Word Length": avg_word_length
    }

# Directory containing the article .txt files
articles_dir = 'scraped_articles'  # Replace with the folder where you saved your articles

# Loop through all .txt files in the articles directory and analyze each
for filename in os.listdir(articles_dir):
    if filename.endswith(".txt"):
        filepath = os.path.join(articles_dir, filename)

        # Read the content of the article
        with open(filepath, 'r', encoding='utf-8', errors='ignore') as file:
            article_text = file.read()

        # Analyze the text
        analysis_result = analyze_text(article_text)

        # Output the results for each file
        print(f"Text Analysis Results for {filename}:")
        print(f"Total Syllables: {analysis_result['Total Syllables']}")
        print(f"Pronoun Count: {analysis_result['Pronoun Count']}")
        print(f"Average Word Length: {analysis_result['Average Word Length']:.2f}")
        print("\n" + "-" * 40 + "\n")  # Separator for better readability
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\abhin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\abhin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Text Analysis Results for bctech2011.txt:
# Total Syllables: 1518
# Pronoun Count: 1
# Average Word Length: 7.59
#
# ----------------------------------------
#
# Text Analysis Results for bctech2012.txt:
# Total Syllables: 497
# Pronoun Count: 1
# Average Word Length: 7.38
#
# ----------------------------------------
#
# Text Analysis Results for bctech2013.txt:
# Total Syllables: 496
# Pronoun Count: 1
# Average Word Length: 7.41
#
# ----------------------------------------
#
# Text Analysis Results for bctech2014.txt:
# Total Syllables: 502
# Pronoun Count: 1
# Average Word Length: 7.41
#
# ----------------------------------------
#
# Text Analysis Results for bctech2015.txt:
# Total Syllables: 504
# Pronoun Count: 1
# Average Word Length: 7.46
#
# ----------------------------------------
#
# Text Analysis Results for bctech2016.txt:
# Total Syllables: 496
# Pronoun Count: 1
# Average Word Length: 7.44
#
# ----------------------------------------
#
# Text Analysis Results for bctech2017.txt:
# Total Syllables: 496
# Pronoun Count: 1
# Average Word Length: 7.33
#
# ----------------------------------------
#
# Text Analysis Results for bctech2018.txt:
# Total Syllables: 497
# Pronoun Count: 1
# Average Word Length: 7.38
#
# ----------------------------------------
#
# Text Analysis Results for bctech2019.txt:
# Total Syllables: 521
# Pronoun Count: 1
# Average Word Length: 7.37
#
# ----------------------------------------
#
# Text Analysis Results for bctech2020.txt:
# Total Syllables: 502
# Pronoun Count: 1
# Average Word Length: 7.43
#
# ----------------------------------------
#
# Text Analysis Results for bctech2021.txt:
# Total Syllables: 510
# Pronoun Count: 1
# Average Word Length: 7.41
#
# ----------------------------------------
#
# Text Analysis Results for bctech2022.txt:
# Total Syllables: 1169
# Pronoun Count: 1
# Average Word Length: 7.11
#
# ----------------------------------------
#
# Text Analysis Results for bctech2023.txt:
# Total Syllables: 906
# Pronoun Count: 1
# Average Word Length: 7.16
#
# ----------------------------------------
#
# Text Analysis Results for bctech2024.txt:
# Total Syllables: 674
# Pronoun Count: 1
# Average Word Length: 7.26
#
# ----------------------------------------
#
# Text Analysis Results for bctech2025.txt:
# Total Syllables: 1107
# Pronoun Count: 1
# Average Word Length: 7.25
#
# ----------------------------------------
#
# Text Analysis Results for bctech2026.txt:
# Total Syllables: 1048
# Pronoun Count: 3
# Average Word Length: 7.36
#
# ----------------------------------------
#
# Text Analysis Results for bctech2027.txt:
# Total Syllables: 969
# Pronoun Count: 1
# Average Word Length: 7.22
#
# ----------------------------------------
#
# Text Analysis Results for bctech2028.txt:
# Total Syllables: 1174
# Pronoun Count: 1
# Average Word Length: 7.23
#
# ----------------------------------------
#
# Text Analysis Results for bctech2029.txt:
# Total Syllables: 1072
# Pronoun Count: 3
# Average Word Length: 7.48
#
# ----------------------------------------
#
# Text Analysis Results for bctech2030.txt:
# Total Syllables: 1096
# Pronoun Count: 1
# Average Word Length: 7.16
#
# ----------------------------------------
#
# Text Analysis Results for bctech2031.txt:
# Total Syllables: 1247
# Pronoun Count: 1
# Average Word Length: 7.14
#
# ----------------------------------------
#
# Text Analysis Results for bctech2032.txt:
# Total Syllables: 651
# Pronoun Count: 1
# Average Word Length: 6.97
#
# ----------------------------------------
#
# Text Analysis Results for bctech2033.txt:
# Total Syllables: 999
# Pronoun Count: 1
# Average Word Length: 7.62
#
# ----------------------------------------
#
# Text Analysis Results for bctech2034.txt:
# Total Syllables: 822
# Pronoun Count: 1
# Average Word Length: 7.46
#
# ----------------------------------------
#
# Text Analysis Results for bctech2035.txt:
# Total Syllables: 980
# Pronoun Count: 1
# Average Word Length: 7.37
#
# ----------------------------------------
#
# Text Analysis Results for bctech2036.txt:
# Total Syllables: 1160
# Pronoun Count: 1
# Average Word Length: 7.20
#
# ----------------------------------------
#
# Text Analysis Results for bctech2037.txt:
# Total Syllables: 1244
# Pronoun Count: 1
# Average Word Length: 6.71
#
# ----------------------------------------
#
# Text Analysis Results for bctech2038.txt:
# Total Syllables: 659
# Pronoun Count: 2
# Average Word Length: 6.92
#
# ----------------------------------------
#
# Text Analysis Results for bctech2039.txt:
# Total Syllables: 626
# Pronoun Count: 1
# Average Word Length: 7.07
#
# ----------------------------------------
#
# Text Analysis Results for bctech2040.txt:
# Total Syllables: 582
# Pronoun Count: 1
# Average Word Length: 7.06
#
# ----------------------------------------
#
# Text Analysis Results for bctech2041.txt:
# Total Syllables: 471
# Pronoun Count: 1
# Average Word Length: 7.25
#
# ----------------------------------------
#
# Text Analysis Results for bctech2042.txt:
# Total Syllables: 537
# Pronoun Count: 1
# Average Word Length: 6.97
#
# ----------------------------------------
#
# Text Analysis Results for bctech2043.txt:
# Total Syllables: 629
# Pronoun Count: 1
# Average Word Length: 6.64
#
# ----------------------------------------
#
# Text Analysis Results for bctech2044.txt:
# Total Syllables: 782
# Pronoun Count: 1
# Average Word Length: 7.08
#
# ----------------------------------------
#
# Text Analysis Results for bctech2045.txt:
# Total Syllables: 658
# Pronoun Count: 1
# Average Word Length: 6.92
#
# ----------------------------------------
#
# Text Analysis Results for bctech2046.txt:
# Total Syllables: 581
# Pronoun Count: 1
# Average Word Length: 7.17
#
# ----------------------------------------
#
# Text Analysis Results for bctech2047.txt:
# Total Syllables: 685
# Pronoun Count: 1
# Average Word Length: 7.15
#
# ----------------------------------------
#
# Text Analysis Results for bctech2048.txt:
# Total Syllables: 586
# Pronoun Count: 1
# Average Word Length: 6.99
#
# ----------------------------------------
#
# Text Analysis Results for bctech2049.txt:
# Total Syllables: 807
# Pronoun Count: 1
# Average Word Length: 6.95
#
# ----------------------------------------
#
# Text Analysis Results for bctech2050.txt:
# Total Syllables: 678
# Pronoun Count: 1
# Average Word Length: 7.12
#
# ----------------------------------------
#
# Text Analysis Results for bctech2051.txt:
# Total Syllables: 801
# Pronoun Count: 1
# Average Word Length: 7.22
#
# ----------------------------------------
#
# Text Analysis Results for bctech2052.txt:
# Total Syllables: 619
# Pronoun Count: 1
# Average Word Length: 6.88
#
# ----------------------------------------
#
# Text Analysis Results for bctech2053.txt:
# Total Syllables: 682
# Pronoun Count: 1
# Average Word Length: 7.00
#
# ----------------------------------------
#
# Text Analysis Results for bctech2054.txt:
# Total Syllables: 714
# Pronoun Count: 1
# Average Word Length: 6.73
#
# ----------------------------------------
#
# Text Analysis Results for bctech2055.txt:
# Total Syllables: 730
# Pronoun Count: 1
# Average Word Length: 6.74
#
# ----------------------------------------
#
# Text Analysis Results for bctech2056.txt:
# Total Syllables: 803
# Pronoun Count: 2
# Average Word Length: 7.07
#
# ----------------------------------------
#
# Text Analysis Results for bctech2057.txt:
# Total Syllables: 654
# Pronoun Count: 1
# Average Word Length: 6.96
#
# ----------------------------------------
#
# Text Analysis Results for bctech2058.txt:
# Total Syllables: 526
# Pronoun Count: 1
# Average Word Length: 7.13
#
# ----------------------------------------
#
# Text Analysis Results for bctech2059.txt:
# Total Syllables: 500
# Pronoun Count: 1
# Average Word Length: 7.26
#
# ----------------------------------------
#
# Text Analysis Results for bctech2060.txt:
# Total Syllables: 533
# Pronoun Count: 1
# Average Word Length: 7.21
#
# ----------------------------------------
#
# Text Analysis Results for bctech2061.txt:
# Total Syllables: 673
# Pronoun Count: 1
# Average Word Length: 7.19
#
# ----------------------------------------
#
# Text Analysis Results for bctech2062.txt:
# Total Syllables: 712
# Pronoun Count: 1
# Average Word Length: 6.73
#
# ----------------------------------------
#
# Text Analysis Results for bctech2063.txt:
# Total Syllables: 543
# Pronoun Count: 1
# Average Word Length: 7.11
#
# ----------------------------------------
#
# Text Analysis Results for bctech2064.txt:
# Total Syllables: 746
# Pronoun Count: 1
# Average Word Length: 7.08
#
# ----------------------------------------
#
# Text Analysis Results for bctech2065.txt:
# Total Syllables: 800
# Pronoun Count: 2
# Average Word Length: 7.12
#
# ----------------------------------------
#
# Text Analysis Results for bctech2066.txt:
# Total Syllables: 635
# Pronoun Count: 1
# Average Word Length: 7.19
#
# ----------------------------------------
#
# Text Analysis Results for bctech2067.txt:
# Total Syllables: 739
# Pronoun Count: 2
# Average Word Length: 7.09
#
# ----------------------------------------
#
# Text Analysis Results for bctech2068.txt:
# Total Syllables: 787
# Pronoun Count: 1
# Average Word Length: 6.98
#
# ----------------------------------------
#
# Text Analysis Results for bctech2069.txt:
# Total Syllables: 579
# Pronoun Count: 1
# Average Word Length: 7.25
#
# ----------------------------------------
#
# Text Analysis Results for bctech2070.txt:
# Total Syllables: 500
# Pronoun Count: 1
# Average Word Length: 7.20
#
# ----------------------------------------
#
# Text Analysis Results for bctech2071.txt:
# Total Syllables: 529
# Pronoun Count: 1
# Average Word Length: 7.26
#
# ----------------------------------------
#
# Text Analysis Results for bctech2072.txt:
# Total Syllables: 545
# Pronoun Count: 1
# Average Word Length: 7.31
#
# ----------------------------------------
#
# Text Analysis Results for bctech2073.txt:
# Total Syllables: 523
# Pronoun Count: 1
# Average Word Length: 7.31
#
# ----------------------------------------
#
# Text Analysis Results for bctech2074.txt:
# Total Syllables: 598
# Pronoun Count: 1
# Average Word Length: 7.33
#
# ----------------------------------------
#
# Text Analysis Results for bctech2075.txt:
# Total Syllables: 706
# Pronoun Count: 1
# Average Word Length: 7.03
#
# ----------------------------------------
#
# Text Analysis Results for bctech2076.txt:
# Total Syllables: 808
# Pronoun Count: 1
# Average Word Length: 7.32
#
# ----------------------------------------
#
# Text Analysis Results for bctech2077.txt:
# Total Syllables: 806
# Pronoun Count: 1
# Average Word Length: 6.87
#
# ----------------------------------------
#
# Text Analysis Results for bctech2078.txt:
# Total Syllables: 879
# Pronoun Count: 1
# Average Word Length: 6.74
#
# ----------------------------------------
#
# Text Analysis Results for bctech2079.txt:
# Total Syllables: 784
# Pronoun Count: 1
# Average Word Length: 7.03
#
# ----------------------------------------
#
# Text Analysis Results for bctech2080.txt:
# Total Syllables: 725
# Pronoun Count: 1
# Average Word Length: 7.19
#
# ----------------------------------------
#
# Text Analysis Results for bctech2081.txt:
# Total Syllables: 1379
# Pronoun Count: 1
# Average Word Length: 7.28
#
# ----------------------------------------
#
# Text Analysis Results for bctech2082.txt:
# Total Syllables: 650
# Pronoun Count: 1
# Average Word Length: 6.98
#
# ----------------------------------------
#
# Text Analysis Results for bctech2083.txt:
# Total Syllables: 794
# Pronoun Count: 1
# Average Word Length: 7.19
#
# ----------------------------------------
#
# Text Analysis Results for bctech2084.txt:
# Total Syllables: 476
# Pronoun Count: 1
# Average Word Length: 7.13
#
# ----------------------------------------
#
# Text Analysis Results for bctech2085.txt:
# Total Syllables: 710
# Pronoun Count: 1
# Average Word Length: 7.18
#
# ----------------------------------------
#
# Text Analysis Results for bctech2086.txt:
# Total Syllables: 700
# Pronoun Count: 1
# Average Word Length: 7.08
#
# ----------------------------------------
#
# Text Analysis Results for bctech2087.txt:
# Total Syllables: 542
# Pronoun Count: 1
# Average Word Length: 7.36
#
# ----------------------------------------
#
# Text Analysis Results for bctech2088.txt:
# Total Syllables: 625
# Pronoun Count: 1
# Average Word Length: 7.30
#
# ----------------------------------------
#
# Text Analysis Results for bctech2089.txt:
# Total Syllables: 640
# Pronoun Count: 1
# Average Word Length: 6.75
#
# ----------------------------------------
#
# Text Analysis Results for bctech2090.txt:
# Total Syllables: 732
# Pronoun Count: 1
# Average Word Length: 7.02
#
# ----------------------------------------
#
# Text Analysis Results for bctech2091.txt:
# Total Syllables: 472
# Pronoun Count: 1
# Average Word Length: 7.19
#
# ----------------------------------------
#
# Text Analysis Results for bctech2092.txt:
# Total Syllables: 589
# Pronoun Count: 1
# Average Word Length: 7.18
#
# ----------------------------------------
#
# Text Analysis Results for bctech2093.txt:
# Total Syllables: 692
# Pronoun Count: 1
# Average Word Length: 7.17
#
# ----------------------------------------
#
# Text Analysis Results for bctech2094.txt:
# Total Syllables: 750
# Pronoun Count: 1
# Average Word Length: 7.01
#
# ----------------------------------------
#
# Text Analysis Results for bctech2095.txt:
# Total Syllables: 637
# Pronoun Count: 1
# Average Word Length: 6.94
#
# ----------------------------------------
#
# Text Analysis Results for bctech2096.txt:
# Total Syllables: 496
# Pronoun Count: 1
# Average Word Length: 7.05
#
# ----------------------------------------
#
# Text Analysis Results for bctech2097.txt:
# Total Syllables: 593
# Pronoun Count: 1
# Average Word Length: 7.17
#
# ----------------------------------------
#
# Text Analysis Results for bctech2098.txt:
# Total Syllables: 688
# Pronoun Count: 1
# Average Word Length: 7.30
#
# ----------------------------------------
#
# Text Analysis Results for bctech2099.txt:
# Total Syllables: 593
# Pronoun Count: 1
# Average Word Length: 7.02
#
# ----------------------------------------
#
# Text Analysis Results for bctech2100.txt:
# Total Syllables: 530
# Pronoun Count: 1
# Average Word Length: 6.94
#
# ----------------------------------------
#
# Text Analysis Results for bctech2101.txt:
# Total Syllables: 594
# Pronoun Count: 1
# Average Word Length: 6.88
#
# ----------------------------------------
#
# Text Analysis Results for bctech2102.txt:
# Total Syllables: 1243
# Pronoun Count: 1
# Average Word Length: 7.01
#
# ----------------------------------------
#
# Text Analysis Results for bctech2103.txt:
# Total Syllables: 1263
# Pronoun Count: 1
# Average Word Length: 6.95
#
# ----------------------------------------
#
# Text Analysis Results for bctech2104.txt:
# Total Syllables: 467
# Pronoun Count: 1
# Average Word Length: 7.25
#
# ----------------------------------------
#
# Text Analysis Results for bctech2105.txt:
# Total Syllables: 640
# Pronoun Count: 1
# Average Word Length: 6.85
#
# ----------------------------------------
#
# Text Analysis Results for bctech2106.txt:
# Total Syllables: 567
# Pronoun Count: 1
# Average Word Length: 7.12
#
# ----------------------------------------
#
# Text Analysis Results for bctech2107.txt:
# Total Syllables: 653
# Pronoun Count: 1
# Average Word Length: 6.90
#
# ----------------------------------------
#
# Text Analysis Results for bctech2108.txt:
# Total Syllables: 641
# Pronoun Count: 2
# Average Word Length: 7.25
#
# ----------------------------------------
#
# Text Analysis Results for bctech2109.txt:
# Total Syllables: 815
# Pronoun Count: 1
# Average Word Length: 7.42
#
# ----------------------------------------
#
# Text Analysis Results for bctech2110.txt:
# Total Syllables: 615
# Pronoun Count: 1
# Average Word Length: 7.08
#
# ----------------------------------------
#
# Text Analysis Results for bctech2111.txt:
# Total Syllables: 681
# Pronoun Count: 1
# Average Word Length: 6.82
#
# ----------------------------------------
#
# Text Analysis Results for bctech2112.txt:
# Total Syllables: 506
# Pronoun Count: 1
# Average Word Length: 7.32
#
# ----------------------------------------
#
# Text Analysis Results for bctech2113.txt:
# Total Syllables: 714
# Pronoun Count: 1
# Average Word Length: 7.00
#
# ----------------------------------------
#
# Text Analysis Results for bctech2114.txt:
# Total Syllables: 419
# Pronoun Count: 1
# Average Word Length: 7.32
#
# ----------------------------------------
#
# Text Analysis Results for bctech2115.txt:
# Total Syllables: 991
# Pronoun Count: 1
# Average Word Length: 6.80
#
# ----------------------------------------
#
# Text Analysis Results for bctech2116.txt:
# Total Syllables: 685
# Pronoun Count: 1
# Average Word Length: 6.53
#
# ----------------------------------------
#
# Text Analysis Results for bctech2117.txt:
# Total Syllables: 722
# Pronoun Count: 1
# Average Word Length: 6.89
#
# ----------------------------------------
#
# Text Analysis Results for bctech2118.txt:
# Total Syllables: 548
# Pronoun Count: 1
# Average Word Length: 7.10
#
# ----------------------------------------
#
# Text Analysis Results for bctech2119.txt:
# Total Syllables: 661
# Pronoun Count: 1
# Average Word Length: 6.79
#
# ----------------------------------------
#
# Text Analysis Results for bctech2120.txt:
# Total Syllables: 692
# Pronoun Count: 1
# Average Word Length: 6.76
#
# ----------------------------------------
#
# Text Analysis Results for bctech2121.txt:
# Total Syllables: 850
# Pronoun Count: 1
# Average Word Length: 6.65
#
# ----------------------------------------
#
# Text Analysis Results for bctech2122.txt:
# Total Syllables: 636
# Pronoun Count: 1
# Average Word Length: 6.78
#
# ----------------------------------------
#
# Text Analysis Results for bctech2123.txt:
# Total Syllables: 705
# Pronoun Count: 3
# Average Word Length: 6.88
#
# ----------------------------------------
#
# Text Analysis Results for bctech2124.txt:
# Total Syllables: 463
# Pronoun Count: 1
# Average Word Length: 7.20
#
# ----------------------------------------
#
# Text Analysis Results for bctech2125.txt:
# Total Syllables: 625
# Pronoun Count: 1
# Average Word Length: 7.45
#
# ----------------------------------------
#
# Text Analysis Results for bctech2126.txt:
# Total Syllables: 515
# Pronoun Count: 1
# Average Word Length: 7.02
#
# ----------------------------------------
#
# Text Analysis Results for bctech2127.txt:
# Total Syllables: 734
# Pronoun Count: 1
# Average Word Length: 7.11
#
# ----------------------------------------
#
# Text Analysis Results for bctech2128.txt:
# Total Syllables: 660
# Pronoun Count: 1
# Average Word Length: 7.04
#
# ----------------------------------------
#
# Text Analysis Results for bctech2129.txt:
# Total Syllables: 412
# Pronoun Count: 2
# Average Word Length: 7.21
#
# ----------------------------------------
#
# Text Analysis Results for bctech2130.txt:
# Total Syllables: 508
# Pronoun Count: 1
# Average Word Length: 7.16
#
# ----------------------------------------
#
# Text Analysis Results for bctech2131.txt:
# Total Syllables: 516
# Pronoun Count: 1
# Average Word Length: 7.14
#
# ----------------------------------------
#
# Text Analysis Results for bctech2132.txt:
# Total Syllables: 470
# Pronoun Count: 1
# Average Word Length: 7.06
#
# ----------------------------------------
#
# Text Analysis Results for bctech2133.txt:
# Total Syllables: 490
# Pronoun Count: 1
# Average Word Length: 7.19
#
# ----------------------------------------
#
# Text Analysis Results for bctech2134.txt:
# Total Syllables: 474
# Pronoun Count: 1
# Average Word Length: 7.20
#
# ----------------------------------------
#
# Text Analysis Results for bctech2135.txt:
# Total Syllables: 678
# Pronoun Count: 2
# Average Word Length: 7.14
#
# ----------------------------------------
#
# Text Analysis Results for bctech2136.txt:
# Total Syllables: 535
# Pronoun Count: 1
# Average Word Length: 7.15
#
# ----------------------------------------
#
# Text Analysis Results for bctech2137.txt:
# Total Syllables: 869
# Pronoun Count: 1
# Average Word Length: 6.90
#
# ----------------------------------------
#
# Text Analysis Results for bctech2138.txt:
# Total Syllables: 620
# Pronoun Count: 1
# Average Word Length: 7.07
#
# ----------------------------------------
#
# Text Analysis Results for bctech2139.txt:
# Total Syllables: 818
# Pronoun Count: 1
# Average Word Length: 7.34
#
# ----------------------------------------
#
# Text Analysis Results for bctech2140.txt:
# Total Syllables: 689
# Pronoun Count: 2
# Average Word Length: 7.14
#
# ----------------------------------------
#
# Text Analysis Results for bctech2141.txt:
# Total Syllables: 707
# Pronoun Count: 1
# Average Word Length: 7.01
#
# ----------------------------------------
#
# Text Analysis Results for bctech2142.txt:
# Total Syllables: 693
# Pronoun Count: 2
# Average Word Length: 7.00
#
# ----------------------------------------
#
# Text Analysis Results for bctech2143.txt:
# Total Syllables: 567
# Pronoun Count: 1
# Average Word Length: 6.95
#
# ----------------------------------------
#
# Text Analysis Results for bctech2144.txt:
# Total Syllables: 550
# Pronoun Count: 1
# Average Word Length: 6.95
#
# ----------------------------------------
#
# Text Analysis Results for bctech2145.txt:
# Total Syllables: 560
# Pronoun Count: 1
# Average Word Length: 7.05
#
# ----------------------------------------
#
# Text Analysis Results for bctech2146.txt:
# Total Syllables: 564
# Pronoun Count: 1
# Average Word Length: 7.06
#
# ----------------------------------------
#
# Text Analysis Results for bctech2147.txt:
# Total Syllables: 557
# Pronoun Count: 1
# Average Word Length: 7.10
#
# ----------------------------------------
#
# Text Analysis Results for bctech2148.txt:
# Total Syllables: 522
# Pronoun Count: 1
# Average Word Length: 7.06
#
# ----------------------------------------
#
# Text Analysis Results for bctech2149.txt:
# Total Syllables: 531
# Pronoun Count: 1
# Average Word Length: 7.06
#
# ----------------------------------------
#
# Text Analysis Results for bctech2150.txt:
# Total Syllables: 558
# Pronoun Count: 2
# Average Word Length: 7.00
#
# ----------------------------------------
#
# Text Analysis Results for bctech2151.txt:
# Total Syllables: 1392
# Pronoun Count: 1
# Average Word Length: 6.81
#
# ----------------------------------------
#
# Text Analysis Results for bctech2152.txt:
# Total Syllables: 1034
# Pronoun Count: 2
# Average Word Length: 7.32
#
# ----------------------------------------
#
# Text Analysis Results for bctech2153.txt:
# Total Syllables: 1450
# Pronoun Count: 1
# Average Word Length: 6.88
#
# ----------------------------------------
#
# Text Analysis Results for bctech2154.txt:
# Total Syllables: 1987
# Pronoun Count: 3
# Average Word Length: 6.65
#
# ----------------------------------------
#
# Text Analysis Results for bctech2155.txt:
# Total Syllables: 577
# Pronoun Count: 1
# Average Word Length: 6.98
#
# ----------------------------------------
#
# Text Analysis Results for bctech2156.txt:
# Total Syllables: 428
# Pronoun Count: 1
# Average Word Length: 7.59
#
# ----------------------------------------
#
# Text Analysis Results for bctech2157.txt:
# Total Syllables: 511
# Pronoun Count: 1
# Average Word Length: 7.06
#
# ----------------------------------------

# %% [markdown]
# ## Output Data Structure.xlsx

# %%
import os
import pandas as pd
import nltk
import re
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

# Ensure you have the necessary resources downloaded
nltk.download('punkt_tab')
nltk.download('stopwords')

# Function to count syllables in a word
def syllable_count(word):
    word = word.lower()
    vowels = "aeiouy"
    count = 0
    is_prev_vowel = False

    for char in word:
        if char in vowels:
            if not is_prev_vowel:
                count += 1
                is_prev_vowel = True
        else:
            is_prev_vowel = False

    # Remove silent 'e' at the end
    if word.endswith("e"):
        count -= 1
    # Handle exceptions for "ed" and "es"
    if word.endswith("ed") or word.endswith("es"):
        count -= 1

    # Ensure count is at least 1
    return max(count, 1)

# Function to count personal pronouns
def count_pronouns(text):
    pronouns_pattern = r'\b(I|we|my|ours|us)\b'
    matches = re.findall(pronouns_pattern, text, flags=re.IGNORECASE)
    return len(matches)

# Function to calculate average word length
def average_word_length(words):
    if not words:
        return 0
    total_characters = sum(len(word) for word in words)
    return total_characters / len(words)

# Function to calculate polarity and subjectivity scores
def calculate_sentiment_scores(positive_score, negative_score, total_words):
    polarity_score = (positive_score - negative_score) / (positive_score + negative_score + 0.000001)
    subjectivity_score = (positive_score + negative_score) / (total_words + 0.000001)
    return polarity_score, subjectivity_score

# Function to analyze text
def analyze_text(text):
    sentences = sent_tokenize(text)
    words = word_tokenize(text)
    stop_words = set(stopwords.words('english'))

    # Clean words (remove stop words and punctuation)
    cleaned_words = [word for word in words if word.isalpha() and word.lower() not in stop_words]

    # Calculate scores for syllables, pronouns, etc.
    syllable_counts = [syllable_count(word) for word in cleaned_words]
    pronoun_count = count_pronouns(text)
    avg_word_length = average_word_length(cleaned_words)

    # Calculate Positive and Negative Scores
    positive_score = sum(1 for word in cleaned_words if word in positive_words)  # Replace with actual positive words
    negative_score = sum(1 for word in cleaned_words if word in negative_words)  # Replace with actual negative words

    # Polarity and Subjectivity Score Calculation
    polarity_score, subjectivity_score = calculate_sentiment_scores(positive_score, negative_score, len(cleaned_words))

    # Average Sentence Length and Fog Index
    avg_sentence_length = len(cleaned_words) / len(sentences) if len(sentences) > 0 else 0
    complex_word_count = sum(1 for word in cleaned_words if syllable_count(word) > 2)
    percentage_complex_words = complex_word_count / len(cleaned_words) if len(cleaned_words) > 0 else 0
    fog_index = 0.4 * (avg_sentence_length + percentage_complex_words)
    avg_words_per_sentence = avg_sentence_length

    return {
        "Positive Score": positive_score,
        "Negative Score": negative_score,
        "Polarity Score": polarity_score,
        "Subjectivity Score": subjectivity_score,
        "Avg Sentence Length": avg_sentence_length,
        "Percentage Complex Words": percentage_complex_words,
        "Fog Index": fog_index,
        "Avg Number of Words per Sentence": avg_words_per_sentence,
        "Complex Word Count": complex_word_count,
        "Word Count": len(cleaned_words),
        "Syllable per Word": sum(syllable_counts) / len(cleaned_words) if len(cleaned_words) > 0 else 0,
        "Personal Pronouns": pronoun_count,
        "Avg Word Length": avg_word_length
    }

# Load the input file that contains URL_ID and URL
input_df = pd.read_excel('Input.xlsx')  # Load your input Excel file

# Directory containing the article .txt files
articles_dir = 'scraped_articles'  # Replace with the folder where you saved your articles

# Data structure to hold the analysis results
output_data = []

# Loop through all .txt files in the articles directory and analyze each
for index, row in input_df.iterrows():
    url_id = row['URL_ID']
    url = row['URL']
    filename = f"{url_id}.txt"  # Assuming the filenames match URL_ID
    
    filepath = os.path.join(articles_dir, filename)
    if os.path.exists(filepath):
        with open(filepath, 'r', encoding='utf-8', errors='ignore') as file:
            article_text = file.read()

        # Analyze the text
        analysis_result = analyze_text(article_text)

        # Add the result to the output data
        output_data.append({
            "URL_ID": url_id,
            "URL": url,
            **analysis_result
        })

# Create a DataFrame from the output data
df = pd.DataFrame(output_data)

# Write the DataFrame to the Output Data Structure
output_file_path = 'Output Data Structure.xlsx'  # Update with the correct path
df.to_excel(output_file_path, index=False)

print("Analysis complete! Data saved to Excel.")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\abhin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\abhin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Analysis complete! Data saved to Excel.

# %% [markdown]
# ## View the saved data in excel

# %%
import pandas as pd

# Load the saved Excel file
df = pd.read_excel('Output Data Structure.xlsx')

# Display the data
print(df)
# Out:
#          URL_ID                                                URL  \
# 0    bctech2011  https://insights.blackcoffer.com/ml-and-ai-bas...
# 1    bctech2012  https://insights.blackcoffer.com/streamlined-i...
# 2    bctech2013  https://insights.blackcoffer.com/efficient-dat...
# 3    bctech2014  https://insights.blackcoffer.com/effective-man...
# 4    bctech2015  https://insights.blackcoffer.com/streamlined-t...
# ..          ...                                                ...
# 142  bctech2153  https://insights.blackcoffer.com/population-an...
# 143  bctech2154  https://insights.blackcoffer.com/google-lsa-ap...
# 144  bctech2155  https://insights.blackcoffer.com/healthcare-da...
# 145  bctech2156  https://insights.blackcoffer.com/budget-sales-...
# 146  bctech2157  https://insights.blackcoffer.com/amazon-buy-bo...
#
#      Positive Score  Negative Score  Polarity Score  Subjectivity Score  \
# 0                34               8        0.619048            0.068966
# 1                 4               0        1.000000            0.019231
# 2                 4               0        1.000000            0.019417
# 3                 4               0        1.000000            0.019231
# 4                 4               0        1.000000            0.019231
# ..              ...             ...             ...                 ...
# 142              10               8        0.111111            0.027907
# 143              14               9        0.217391            0.024339
# 144               9               6        0.200000            0.058366
# 145               3               0        1.000000            0.017544
# 146               5               0        1.000000            0.022624
#
#      Avg Sentence Length  Percentage Complex Words  Fog Index  \
# 0              26.478261                  0.438424  10.766674
# 1              34.666667                  0.370192  14.014744
# 2              34.333333                  0.393204  13.890615
# 3              34.666667                  0.384615  14.020513
# 4              34.666667                  0.394231  14.024359
# ..                   ...                       ...        ...
# 142            17.432432                  0.336434   7.107547
# 143            13.897059                  0.268783   5.666337
# 144            18.357143                  0.315175   7.468927
# 145            42.750000                  0.397661  17.259064
# 146            22.100000                  0.366516   8.986606
#
#      Avg Number of Words per Sentence  Complex Word Count  Word Count  \
# 0                           26.478261                 267         609
# 1                           34.666667                  77         208
# 2                           34.333333                  81         206
# 3                           34.666667                  80         208
# 4                           34.666667                  82         208
# ..                                ...                 ...         ...
# 142                         17.432432                 217         645
# 143                         13.897059                 254         945
# 144                         18.357143                  81         257
# 145                         42.750000                  68         171
# 146                         22.100000                  81         221
#
#      Syllable per Word  Personal Pronouns  Avg Word Length
# 0             2.492611                  1         7.587849
# 1             2.389423                  1         7.384615
# 2             2.407767                  1         7.412621
# 3             2.413462                  1         7.408654
# 4             2.423077                  1         7.456731
# ..                 ...                ...              ...
# 142           2.248062                  1         6.880620
# 143           2.102646                  3         6.645503
# 144           2.245136                  1         6.976654
# 145           2.502924                  1         7.590643
# 146           2.312217                  1         7.063348
#
# [147 rows x 15 columns]
